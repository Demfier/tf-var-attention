# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

import sys

if not '../' in sys.path: sys.path.append('../')

import pandas as pd

from utils import data_utils
from model_config import config
from ved_varAttn import VarSeq2SeqVarAttnModel
# Out:
# Using TensorFlow backend.

# %%
if config['experiment'] == 'qgen':
    print('[INFO] Preparing data for experiment: {}'.format(config['experiment']))
    train_data = pd.read_csv(config['data_dir'] + 'df_qgen_train.csv')
    val_data = pd.read_csv(config['data_dir'] + 'df_qgen_val.csv')
    test_data = pd.read_csv(config['data_dir'] + 'df_qgen_test.csv')
    input_sentences = pd.concat([train_data['answer'], val_data['answer'], test_data['answer']])
    output_sentences = pd.concat([train_data['question'], val_data['question'], test_data['question']])
    true_test = test_data['question']
    input_test = test_data['answer']
    filters = '!"#$%&()*+,./:;<=>?@[\\]^`{|}~\t\n'
    w2v_path = config['w2v_dir'] + 'w2vmodel_qgen.pkl'
    
elif config['experiment'] == 'dialogue':
    train_data = pd.read_csv(config['data_dir'] + 'df_dialogue_train.csv')
    val_data = pd.read_csv(config['data_dir'] + 'df_dialogue_val.csv')
    test_data = pd.read_csv(config['data_dir'] + 'df_dialogue_test.csv')
    input_sentences = pd.concat([train_data['line'], val_data['line'], test_data['line']])
    output_sentences = pd.concat([train_data['reply'], val_data['reply'], test_data['reply']])
    true_test = test_data['reply']
    input_test = test_data['line']
    filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
    w2v_path = config['w2v_dir'] + 'w2vmodel_dialogue.pkl'

elif config['experiment'] == 'arc':
        train_data = pd.read_csv(config['data_dir'] + 'df_arc_train.csv')
        val_data = pd.read_csv(config['data_dir'] + 'df_arc_val.csv')
        test_data = pd.read_csv(config['data_dir'] + 'df_arc_test.csv')
        input_sentences = pd.concat([train_data['ProductSent'],
                                    val_data['ProductSent'],
                                    test_data['ProductSent']])
        output_sentences = pd.concat([train_data['ProductPhrase'],
                                      val_data['ProductPhrase'],
                                      test_data['ProductPhrase']])
        true_test = test_data['ProductPhrase']
        input_test = test_data['ProductSent']
        filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
        w2v_path = config['w2v_dir'] + 'w2vmodel_arc.pkl'

elif config['experiment'] == 'arc2':
        train_data = pd.read_csv(config['data_dir'] + 'df_arc2_train.csv')
        val_data = pd.read_csv(config['data_dir'] + 'df_arc2_val.csv')
        test_data = pd.read_csv(config['data_dir'] + 'df_arc2_test.csv')
        input_sentences = pd.concat([train_data['Review-Sent'],
                                    val_data['Review-Sent'],
                                    test_data['Review-Sent']])
        output_sentences = pd.concat([train_data['Categories'],
                                      val_data['Categories'],
                                      test_data['Categories']])
        true_test = test_data['Categories']
        input_test = test_data['Review-Sent']
        filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
        w2v_path = config['w2v_dir'] + 'w2vmodel_arc.pkl'
else:
    print('Invalid experiment name specified!')

# %%
print('[INFO] Tokenizing input and output sequences')
x, input_word_index = data_utils.tokenize_sequence(input_sentences, 
                                                                      filters, 
                                                                      config['encoder_num_tokens'], 
                                                                      config['encoder_vocab'])

y, output_word_index = data_utils.tokenize_sequence(output_sentences, 
                                                                        filters, 
                                                                        config['decoder_num_tokens'], 
                                                                        config['decoder_vocab'])

print('[INFO] Split data into train-validation-test sets')
x_train, y_train, x_val, y_val, x_test, y_test = data_utils.create_data_split(x, 
                                                                              y, 
                                                                              config['experiment'])

encoder_embeddings_matrix = data_utils.create_embedding_matrix(input_word_index, 
                                                               config['embedding_size'], 
                                                               w2v_path)

decoder_embeddings_matrix = data_utils.create_embedding_matrix(output_word_index, 
                                                               config['embedding_size'], 
                                                               w2v_path)

# Re-calculate the vocab size based on the word_idx dictionary
config['encoder_vocab'] = len(input_word_index)
config['decoder_vocab'] = len(output_word_index)
# Out:
# [INFO] Tokenizing input and output sequences
# [INFO] Split data into train-validation-test sets

# %%
model = VarSeq2SeqVarAttnModel(config, 
                               encoder_embeddings_matrix, 
                               decoder_embeddings_matrix, 
                               input_word_index, 
                               output_word_index)
# Out:
# [INFO] Building Model ...
# WARNING:tensorflow:From /home/gaurav/.local/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py:430: calling reverse_sequence (from tensorflow.python.ops.array_ops) with seq_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# seq_dim is deprecated, use seq_axis instead
# WARNING:tensorflow:From /home/gaurav/.local/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:454: calling reverse_sequence (from tensorflow.python.ops.array_ops) with batch_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# batch_dim is deprecated, use batch_axis instead
# WARNING:tensorflow:From /home/gaurav/tf-var-attention/ved_varAttn/varAttention_decoder/attention_wrapper.py:1032: calling count_nonzero (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
if config['load_checkpoint'] != 0: 
    checkpoint = config['model_checkpoint_dir'] + str(config['load_checkpoint']) + '.ckpt'
else:
    checkpoint = tf.train.get_checkpoint_state(os.path.dirname('models/checkpoint')).model_checkpoint_path

preds = model.predict(checkpoint, 
                      x_test, 
                      y_test, 
                      true_test, 
                      )
# Out:
# INFO:tensorflow:Restoring parameters from models/var-seq2seq-var-attn-24.ckpt
# BLEU 1 to 4 : 40.68 | 34.07 | 31.13 | 29.04

# %%
count = 100
model.show_output_sentences(preds[:count], 
                            y_test[:count], 
                            input_test[:count], 
                            true_test[:count], 
                            )
# Out:
# Input:      i have been using science diet for my toy yorkies for many years  until i found wellness formula .
# Actual:     pet supplies,toothpaste,health supplies,dental care,dogs
# Generated: fat burners , supplements , vitamins and dietary supplements ,
#
# Input:      i 've also used it on a propane burner normally used for crawfish boils and fried turkeys .
# Actual:     patio,grills and outdoor cooking,smokers,lawn and garden,smokers and combination grill-smokers
# Generated: grills and outdoor cooking , combination grill-smokers , lawn and
#
# Input:      we have used them for various temperatures from baking pans  baking stones and the barbeque all with great results .
# Actual:     protective mitts and potholders,grill and smoker parts and accessories,grills and outdoor cooking,cooking tools and accessories,lawn and garden, patio
# Generated: outdoor gear , camping and hiking , campfire cookware ,
#
# Input:      it also has an intangible quality ... it has a satisfying feel when using the knife for all kinds of outdoor tasks etc. .
# Actual:     tactical and duty,hunting and fishing,tactical knives
# Generated: chefs knives , kitchen and dining , kitchen knives and
#
# Input:      i use the leatherman wave at my job for cutting  striping  and repairs .
# Actual:     multitools and accessories,power and hand tools,hand tools,multitools
# Generated: hunting knives , hunting and fishing , hunting , hunting
#
# Input:      you can also use this for various exercises  and it comes with an instruction manual on how to perform them .
# Actual:     massage and relaxation,massage tools,health care,back massagers
# Generated: accessories , exercise and fitness , exercise bands
#
# Input:      i used the powder brush for foundations the foundation brush for concealer and the detail brush for my inner eye shadow .
# Actual:     tools and accessories,brushes and applicators,makeup brushes and tools
# Generated: tools and accessories , brushes and applicators , makeup brushes
#
# Input:      we have been using it for 1.5 yaars .
# Actual:     stick vacuums and electric brooms,vacuums,vacuums and floor care
# Generated: baby
#
# Input:      for day naps he was a little more reluctant so we continued using the sleeper for the next couple of weeks .
# Actual:     baby
# Generated: baby
#
# Input:      i will no doubt have more uses for the skillet once i receive the lid .
# Actual:     cookware,kitchen and dining,skillets
# Generated: cookware , kitchen and dining , skillets
#
# Input:      for the women-if you use it down there  it will keep you from ever having another yeast infection ... but unless you 're feeling super kinky  do n't use peppermint  because it will kill you in that region .
# Actual:     outdoor gear,camping and hiking,personal care,soap and shampoo
# Generated: pet supplies , health supplies , ear care , dogs
#
# Input:      i am using it for weight watchers and it helps measure out my food quickly .
# Actual:     measuring tools and scales,scales,kitchen utensils and gadgets,digital scales,kitchen and dining
# Generated: measuring tools and scales , scales , kitchen utensils and
#
# Input:      now he uses it for the jumping function .
# Actual:     baby
# Generated: baby
#
# Input:      buy this lantern  it 's amazing  it 's extremely compact  a very rugged build  runs on 3d batteries and it has a very strong light  i will use it for camping and hanging in my tent  but this thing lights up my entire room .
# Actual:     outdoor gear,camping and hiking,lanterns,lights and lanterns
# Generated: outdoor gear , camping and hiking , lanterns , lights
#
# Input:      i bought it hoping i can use it for the stairs but i think it 'll take too long for it to cover the entire area ; however  i must say that it works wonders in the bathroom and kitchen picking up cat litter  hair  and minor debris .
# Actual:     handheld vacuums,vacuums,vacuums and floor care
# Generated: handheld vacuums , vacuums , vacuums and floor care
#
# Input:      they are larger than the cup/saucer type of other sets so they are also more functional than just being used for coffee .
# Actual:     dinnerware sets,kitchen and dining,dining and entertaining
# Generated: baby
#
# Input:      i was not sure of the device after using magicjack for a couple of years .
# Actual:     voip,adapters,office electronics,telephones and accessories, office products
# Generated: voip , adapters , office electronics , telephones and accessories
#
# Input:      i still keep my old featherlight vaccuum though for the stairs  as this one is a bit challenging to manuever up and down a long flight of stairs  even using the attachments .
# Actual:     upright vacuums,vacuums,vacuums and floor care
# Generated: handheld vacuums , vacuums , vacuums and floor care
#
# Input:      we simply ran 3 brews of water and vinegar before using for coffee .
# Actual:     coffee,tea and espresso,coffee makers,coffee machines,kitchen and dining
# Generated: coffee , tea and espresso , coffee makers , single-serve
#
# Input:      this little pump is a real workhorse we used it for our septic problem and it performed great i am pleased with the pump and highly recommend it
# Actual:     sump pumps,rough plumbing,water pumps and accessories
# Generated: baby
#
# Input:      you 'll want to go with the bigger model if you are planning on using this for a big family .
# Actual:     kitchen and dining,juicers,centrifugal juicers,small appliances
# Generated: baby
#
# Input:      there is a simple manual operation button that can be used for quick manual applications .
# Actual:     gardening and lawn care,watering equipment,hose timers,lawn and garden, patio
# Generated: baby
#
# Input:      i 've used all of the tools at one point except for the toothpick .
# Actual:     outdoor gear,camping and hiking,folding knives,knives and tools
# Generated: multitools and accessories , power and hand tools , hand
#
# Input:      :-rrb- i 've been using it several times per day for about 5 minutes each time and i absolutely love it .
# Actual:     massage and relaxation,massage tools,health care,back massagers
# Generated: pet supplies , shedding tools , grooming , dogs
#
# Input:      i originally found the blue/green striped one at babies-r-us and have been using it for a while  but the camo is too cute !
# Actual:     baby
# Generated: baby
#
# Input:      but she ca n't use tampons for the same reason.it also shortened my period down to 5 or less days  which is great .
# Actual:     alternative protection,personal care,feminine care
# Generated: alternative protection , personal care , feminine care
#
# Input:      i 've used this for two growing seasons .
# Actual:     lawn and garden,roll into spring, patio,lawn care
# Generated: gardening and lawn care , cold frames , greenhouses and
#
# Input:      i use it for my foundation and it always gives an airbrush kind of finish  no streaks and beautiful .
# Actual:     tools and accessories,brushes and applicators,makeup brushes and tools
# Generated: tools and accessories , brushes and applicators , makeup brushes
#
# Input:      we 've been using frontline for our dog for years  amazon has really made it \ `` affordable \ '' compared to the other suppliers.the frontline product works well  but i do hate the oily mess when it comes to putting it on the dog .
# Actual:     pet supplies,health supplies,dogs,lice and tick control,flea,flea drops
# Generated: pet supplies , health supplies , dogs , lice and
#
# Input:      i use the 1 scoop of coffee for each cup of water -lrb- 5 oz . -rrb-
# Actual:     coffee,tea and espresso,coffee makers,coffee machines,kitchen and dining
# Generated: coffee , tea and espresso , coffee makers , coffee
#
# Input:      i 'd loaned out my blender over a year ago and never missed it  because i got addicted to using a wand-type hand blender for just about everything .
# Actual:     kitchen and dining,small appliances,blenders,personal size blenders
# Generated: kitchen and dining , small appliances , blenders , personal
#
# Input:      i use it for bikram yoga -lrb- 100 + degree room -rrb- and most of the time end up putting too much ice in it as the ice does not melt to make more water for me .
# Actual:     accessories,sports water bottles
# Generated: yoga , exercise and fitness , mats
#
# Input:      i decided to use it as night for best results .
# Actual:     face,skin care,oils and serums
# Generated: alternative medicine , health care , light therapy
#
# Input:      we are using this for our daughters clothes instead of dreft .
# Actual:     liquid detergent,laundry,household supplies
# Generated: laundry , household supplies , powder detergent
#
# Input:      for the stairs  we used a different led light with fewer bulbs and a shorter shutoff time  as less light was needed there.although we tend to use them in stationary applications  they are obviously quite portable and make a good ad-hoc flashlight.when this light is getting its typical use in the closet  it takes a long time for the batteries to run down  and you do get a bit of warning as the light begins to get dim when they 're running low .
# Actual:     under-cabinet lights,lighting and ceiling fans,wall lights
# Generated: electrical , light bulbs , led bulbs
#
# Input:      it works great to mix dough for pizza  for instance  but for the most part we just use it to bake bread in the machine itself .
# Actual:     kitchen and dining,bread machines,small appliances
# Generated: mixers , stand mixers , kitchen and dining , small
#
# Input:      there are millions of uses  but these are what i use it for with much success .
# Actual:     outdoor gear,camping and hiking,personal care,soap and shampoo
# Generated: baby
#
# Input:      we really like these brushes ... along with using them for nail art  they can be used for highlighting for henna !
# Actual:     tools and accessories,nail tools,nail art equipment
# Generated: tools and accessories , nail tools , nail art equipment
#
# Input:      i also use it in my diffuser once in a while and will use it for the baby .
# Actual:     massage and relaxation,oils,health care,aromatherapy
# Generated: shaving and hair removal , personal care , electric shavers
#
# Input:      after installing the stand  it has fulfilled my expectations.first  it does the basics quite well - i use it for my dell laptop -lrb- 12 \ '' wide x 8 \ '' deep plus protruding battery -rrb- .
# Actual:     notebook computer stands,platforms,office and school supplies,desk accessories and workspace organizers,stands and shelves, office products
# Generated: medical supplies and equipment , blood pressure monitors , health
#
# Input:      i use it for workouts  and i 'm also wearing it during the day to see what it 'll do to my waist size .
# Actual:     medical supplies and equipment,braces,splints and supports
# Generated: medical supplies and equipment , heart rate monitors , health
#
# Input:      i bought it initially so i could use it for my sewing machine but i may need to put a printer on it .
# Actual:     patio furniture and accessories,shade sails,canopies and shade,umbrellas,lawn and garden, patio
# Generated: patio furniture and accessories , shade sails , canopies and
#
# Input:      i also use it for homemade peppermint marshmallows .
# Actual:     herbal supplements,vitamins and dietary supplements
# Generated: herbal supplements , vitamins and dietary supplements
#
# Input:      i now use my fiskars for all my mowing .
# Actual:     lawn mowers and tractors,walk-behind lawn mowers,lawn mowers and outdoor power tools,lawn and garden, patio
# Generated: personal protective equipment , safety and security , safety ear
#
# Input:      i only started to use it for the first time couple of days ago .
# Actual:     stick vacuums and electric brooms,vacuums,vacuums and floor care
# Generated: outdoor gear , camping and hiking , camp kitchen ,
#
# Input:      it really works :-rrb- i used it for my plantar fascilitis and my knees .
# Actual:     plantar fasciitis braces,braces,splints and supports,leg and foot supports,medical supplies and equipment
# Generated: plantar fasciitis braces , braces , splints and supports ,
#
# Input:      i bought an item with a similar concept with my first child with clips and intended to use it for her stroller  but the clips never worked and she did n't find the toy interesting .
# Actual:     baby
# Generated: baby
#
# Input:      i previously used a wrist monitor for work and found it to be inconsistent .
# Actual:     medical supplies and equipment,blood pressure monitors,health and wellness monitors,activity
# Generated: baby
#
# Input:      i 've only used this for hot food  my morning breakfast .
# Actual:     baby
# Generated: sports nutrition
#
# Input:      i 'm not using this for camping or tailgating .
# Actual:     grills,outdoor gear,camping and hiking,stove accessories,camp kitchen
# Generated: outdoor gear , camping and hiking , camp bedding ,
#
# Input:      very pleased with quality and overall product.i used my paracord for multiple things .
# Actual:     tactical and duty,hunting and fishing,paracords
# Generated: tactical and duty , hunting and fishing , paracords
#
# Input:      it runs on regular batteries  which is great -- honestly  if i have to remember to recharge one more thing in my apartment i 'll go nuts.yes  you really can have up to 8 people use this for their individual accounts .
# Actual:     digital,bath,scales,bathroom accessories
# Generated: flashlights , handheld flashlights , hand tools , power and
#
# Input:      i do n't use it for photos  just and#34; regular and#34; printing jobs  and it does the job quickly and efficiently .
# Actual:     printers and accessories,inkjet printers,office electronics,printers, office products
# Generated: office electronics , scanners , office products , scanners and
#
# Input:      using a mask or caring for your face is not a girl thing to do  its a skin thing ... if that makes any sense ... even if it were to pull up more sebum  or create a few more oncoming pimples  i will say for sure that with proper use -lrb- following directions -rrb-  or even taking the steps i did  that it will clear up your skin .
# Actual:     cleansers,face,skin care
# Generated: scrubs , face , exfoliators and scrubs ,
#
# Input:      i like that it ca n't hurt my dogs or child and can be used for other things being food-grade .
# Actual:     gardening and lawn care,fertilizers and mulches,fertilizers and plant food,soils,lawn and garden, patio
# Generated: baby
#
# Input:      this is selectable and can be used all year for all seasons for heaters and fans .
# Actual:     heating and cooling,building supplies,thermostats,programmable,thermostats and accessories
# Generated: gardening and lawn care , watering equipment , sprinklers ,
#
# Input:      my wife uses this product regularly for chronic foot/ankle tendonitis and says it 's great .
# Actual:     plantar fasciitis braces,braces,splints and supports,leg and foot supports,medical supplies and equipment
# Generated: plantar fasciitis braces , braces , splints and supports ,
#
# Input:      it says that you can only use it for cold liquids  but i 've been using it forever for my morning coffee and never had a problem .
# Actual:     storage and organization,thermoses,kitchen and dining
# Generated: glassware and drinkware , tumblers , kitchen and dining ,
#
# Input:      use it for baby clothing and tide is a brand i trust to get our clothing clean .
# Actual:     liquid detergent,laundry,household supplies
# Generated: baby
#
# Input:      if your hair is super thin or you 're using these for a little girl  try some dry shampoo before you curl -- that might help !
# Actual:     styling tools,hair rollers,hair care
# Generated: massage oils , massage and relaxation , health care
#
# Input:      even brooms  etc. without large handles will fit ; i used it for my umbrellas as well as mops and dusters .
# Actual:     storage and home organization,garage storage,wall racks
# Generated: baby
#
# Input:      i use to keep my spare battery in the garage charged for using 12 volt items instead of using my cars for the power .
# Actual:     battery chargers,jump starters,tools and equipment,battery chargers and portable power
# Generated: battery chargers , jump starters , tools and equipment ,
#
# Input:      after using the red wine aerator for a number of years  decided to try the white version .
# Actual:     wine accessories,kitchen and dining,wine accessory sets
# Generated: wine accessories , kitchen and dining , wine accessory sets
#
# Input:      i use mine for pistol shooting .
# Actual:     eyewear and hearing protection,hunting and fishing,hunting,earmuffs
# Generated: eyewear and hearing protection , hunting and fishing , hunting
#
# Input:      i mainly use it for work but it is so handy for any use it is the only knife i carry for daily use .
# Actual:     hunting knives,hunting and fishing,hunting,hunting and tactical knives,folding hunting knives
# Generated: flashlights , handheld flashlights , hand tools , power and
#
# Input:      it is a toxin so you really do n't want to use it for no reason .
# Actual:     pet supplies,health supplies,dogs,lice and tick control,flea,flea drops
# Generated: baby
#
# Input:      i have not used it for a lot of time .
# Actual:     printers and accessories,office electronics,printers,laser printers, office products
# Generated: kitchen and dining , blenders , hand blenders , small
#
# Input:      i use a burr grinder for coffee  but because i live on the big island of hawaii  i have access to some really fine coffee ; which i often send to friends .
# Actual:     kitchen and dining,coffee,coffee grinders,tea and espresso
# Generated: kitchen and dining , coffee , coffee grinders , tea
#
# Input:      i have a 2004 gmc z-71 and have used it mainly for personal pleasure and pulling our travel trailer .
# Actual:     trailer accessories,brake controls,exterior accessories
# Generated: gardening and lawn care , machetes , lawn and garden
#
# Input:      i am an m.d. and i use this for my low back pain .
# Actual:     alternative medicine,health care,manipulation therapies
# Generated: alternative medicine , health care , manipulation therapies
#
# Input:      if i use the jar for cold foods including a small salad  i put the jar in the freezer while i prepare the cold foods ; it stays cold all day even if i do n't have time to eat the food .
# Actual:     baby
# Generated: kitchen and dining , blenders , hand blenders , small
#
# Input:      we use the larger ones for cocktails and other drinks .
# Actual:     specialty tools and gadgets,ice cube molds and trays,kitchen and dining,kitchen utensils and gadgets
# Generated: baby
#
# Input:      i 've used it for a few different things : eczema - i 've had eczema off and on for most of my life and this stuff just makes it vanish.dry hands - my husband and i get really bad dry winter hands .
# Actual:     body,oils,skin care,moisturizers
# Generated: body , oils , skin care , moisturizers
#
# Input:      i have thick asian hair and have been using 1875 watt dryers for at least a decade -lrb- how else can i dry my hair under an hour ? -rrb-
# Actual:     styling tools,hair dryers,hair care
# Generated: styling tools , flattening irons , hair care , irons
#
# Input:      now i 'm using it for my 6 week old son  and it is vastly  vastly superior to the smaller infant tub .
# Actual:     baby
# Generated: baby
#
# Input:      i use this curler for my long hair extensions.it curls very quickly but you need to be careful .
# Actual:     styling tools,hair care,irons,curling irons
# Generated: styling tools , flattening irons , hair care , irons
#
# Input:      use it for home office with timewwarner digital phone .
# Actual:     cordless telephones,office electronics, office products,telephones and accessories
# Generated: cordless telephones , office electronics , office products , telephones
#
# Input:      they are all i use for water  coffee or tea .
# Actual:     glassware and drinkware,tumblers,kitchen and dining,dining and entertaining
# Generated: glassware and drinkware , tumblers , kitchen and dining ,
#
# Input:      note that you can not use this if you have an alarm system that requires a land line  and you can not use this for 911 calls .
# Actual:     voip,adapters,office electronics,telephones and accessories, office products
# Generated: voip , adapters , office electronics , telephones and accessories
#
# Input:      i 've only been using bare minerals for a couple of days but have noticed a huge difference it does n't look like i am wearing makeup but the acne scars are hidden .
# Actual:     makeup,face,foundation
# Generated: makeup , face , foundation
#
# Input:      it 's going to be kept on his boat and used for day trips when he wants to make a quick burger without smelling up the cabin .
# Actual:     grills,outdoor gear,camping and hiking,stove accessories,camp kitchen
# Generated: battery chargers , jump starters , tools and equipment ,
#
# Input:      the extra long nylon cord can be used for so many things in survival situations and the fire starter works great .
# Actual:     hunting knives,fixed blade hunting knives,hunting and fishing,hunting,hunting and tactical knives
# Generated: tactical and duty , hunting and fishing , paracords
#
# Input:      i used it for 4 nights .
# Actual:     bedding,pillows and accessories,inflatable beds
# Generated: outdoor gear , camping and hiking , camp bedding ,
#
# Input:      since i use it for my dog  he tends to get the panels dirty .
# Actual:     baby
# Generated: pet supplies , kennels and pens , houses , crates
#
# Input:      i 've had this a couple of months now and have used it for a wide variety of foods and is has worked great .
# Actual:     dehydrators,kitchen and dining,specialty appliances,small appliances
# Generated: tactical and duty , hunting and fishing , paracords
#
# Input:      after we moved  we still used the gate for our son to keep him out of the rest of our house -lrb- down the hallway and into bedrooms and bathrooms -rrb- and it also did a wonderful job keeping our dog out too !
# Actual:     baby
# Generated: baby
#
# Input:      i use it for every thing from frying to steaming to boiling .
# Actual:     grills and outdoor cooking,combination grill-smokers,lawn and garden, patio,smokers and combination grill-smokers
# Generated: cookware , kitchen and dining , skillets
#
# Input:      i also use a yoga towel for any hot classes to prevent slipping . -rrb-
# Actual:     yoga,exercise and fitness,mats
# Generated: yoga , exercise and fitness , mats
#
# Input:      we 've used it for a couple of months now  and have had to replace the battery once .
# Actual:     pet supplies,collars,harnesses and leashes,bark collars,dogs
# Generated: baby
#
# Input:      my friend used his gate for his baby .
# Actual:     baby
# Generated: baby
#
# Input:      we used this for an aromatic scented night light -lrb- the kind with scented wax on the top  heated with a light bulb -rrb- .
# Actual:     electrical,home automation devices,modules
# Generated: baby
#
# Input:      we use it for personal/small business purpose and works nice .
# Actual:     cordless telephones,office electronics, office products,telephones and accessories
# Generated: printers and accessories , office electronics , printers , laser
#
# Input:      then i have used this at home for the past 2 self - manis .
# Actual:     top and base coats,makeup,nails
# Generated: shaving and hair removal , personal care , manual shaving
#
# Input:      no higher than medium high heat is used for best results on top of the stove .
# Actual:     cookware,kitchen and dining,dutch ovens
# Generated: cookware , kitchen and dining , skillets
#
# Input:      i like the fact that it can be used either for hot or cold liquids .
# Actual:     kitchen and dining,blenders,hand blenders,small appliances
# Generated: storage and organization , kitchen and dining
#
# Input:      i have used it for 3 workouts this week .
# Actual:     accessories,exercise and fitness,sauna suits
# Generated: medical supplies and equipment , heart rate monitors , health
#
# Input:      also you will have to grind multiple batches  just to have about 3 cups of ground coffee.i would highly recommend that you purchase two -lrb- perhaps in two different colors -rrb-  so that one can be used only for coffee-make sure you wipe it clean after every coffee grind  since the oils in the coffee beans can create a rancid smell-and the other in place of many things you would use for a mortar and pestle .
# Actual:     kitchen and dining,coffee,coffee grinders,tea and espresso
# Generated: kitchen and dining , coffee , coffee grinders , tea
#
# Input:      i can use it as a conditioner  coz i still ca n't stand it if i do n't shampoo my hair at least twice/week  but the rest of the days i just use wen for my everyday wash and it does n't dry my hair or make it limp .
# Actual:     conditioners,hair care
# Generated: conditioners , hair care
#
# Input:      this is a beautiful  high quality carrier that i use for my cat .
# Actual:     pet supplies,soft-sided carriers,carriers and travel products,dogs,carriers
# Generated: pet supplies , kennels and pens , houses , crates
#
# Input:      my little ones are even figuring out how to use them for support in the pool now as they learn to kick  splash and play .
# Actual:     safety and flotation devices,life jackets and vests,boating and water sports,boating
# Generated: baby

# %%
model.get_diversity_metrics(checkpoint, x_test, y_test)
# Out:
# INFO:tensorflow:Restoring parameters from models/var-seq2seq-var-attn-24.ckpt
# 100%|██████████| 3/3 [02:23<00:00, 47.94s/it]
# Entropy = 1.643 | Distinct-1 = 0.107 | Distinct-2 = 0.143
