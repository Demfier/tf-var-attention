# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

import sys

if not '../' in sys.path: sys.path.append('../')

import pandas as pd

from utils import data_utils
from model_config import config
from ved_varAttn import VarSeq2SeqVarAttnModel
# Out:
# Using TensorFlow backend.

# %%
if config['experiment'] == 'qgen':
    print('[INFO] Preparing data for experiment: {}'.format(config['experiment']))
    train_data = pd.read_csv(config['data_dir'] + 'df_qgen_train.csv')
    val_data = pd.read_csv(config['data_dir'] + 'df_qgen_val.csv')
    test_data = pd.read_csv(config['data_dir'] + 'df_qgen_test.csv')
    input_sentences = pd.concat([train_data['answer'], val_data['answer'], test_data['answer']])
    output_sentences = pd.concat([train_data['question'], val_data['question'], test_data['question']])
    true_test = test_data['question']
    input_test = test_data['answer']
    filters = '!"#$%&()*+,./:;<=>?@[\\]^`{|}~\t\n'
    w2v_path = config['w2v_dir'] + 'w2vmodel_qgen.pkl'
    
elif config['experiment'] == 'dialogue':
    train_data = pd.read_csv(config['data_dir'] + 'df_dialogue_train.csv')
    val_data = pd.read_csv(config['data_dir'] + 'df_dialogue_val.csv')
    test_data = pd.read_csv(config['data_dir'] + 'df_dialogue_test.csv')
    input_sentences = pd.concat([train_data['line'], val_data['line'], test_data['line']])
    output_sentences = pd.concat([train_data['reply'], val_data['reply'], test_data['reply']])
    true_test = test_data['reply']
    input_test = test_data['line']
    filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
    w2v_path = config['w2v_dir'] + 'w2vmodel_dialogue.pkl'

elif config['experiment'] == 'arc':
        train_data = pd.read_csv(config['data_dir'] + 'df_arc_train.csv')
        val_data = pd.read_csv(config['data_dir'] + 'df_arc_val.csv')
        test_data = pd.read_csv(config['data_dir'] + 'df_arc_test.csv')
        input_sentences = pd.concat([train_data['ProductSent'],
                                    val_data['ProductSent'],
                                    test_data['ProductSent']])
        output_sentences = pd.concat([train_data['ProductPhrase'],
                                      val_data['ProductPhrase'],
                                      test_data['ProductPhrase']])
        true_test = test_data['ProductPhrase']
        input_test = test_data['ProductSent']
        filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
        w2v_path = config['w2v_dir'] + 'w2vmodel_arc.pkl'

else:
    print('Invalid experiment name specified!')

# %%
print('[INFO] Tokenizing input and output sequences')
x, input_word_index = data_utils.tokenize_sequence(input_sentences, 
                                                                      filters, 
                                                                      config['encoder_num_tokens'], 
                                                                      config['encoder_vocab'])

y, output_word_index = data_utils.tokenize_sequence(output_sentences, 
                                                                        filters, 
                                                                        config['decoder_num_tokens'], 
                                                                        config['decoder_vocab'])

print('[INFO] Split data into train-validation-test sets')
x_train, y_train, x_val, y_val, x_test, y_test = data_utils.create_data_split(x, 
                                                                              y, 
                                                                              config['experiment'])

encoder_embeddings_matrix = data_utils.create_embedding_matrix(input_word_index, 
                                                               config['embedding_size'], 
                                                               w2v_path)

decoder_embeddings_matrix = data_utils.create_embedding_matrix(output_word_index, 
                                                               config['embedding_size'], 
                                                               w2v_path)

# Re-calculate the vocab size based on the word_idx dictionary
config['encoder_vocab'] = len(input_word_index)
config['decoder_vocab'] = len(output_word_index)
# Out:
# [INFO] Tokenizing input and output sequences
# [INFO] Split data into train-validation-test sets

# %%
model = VarSeq2SeqVarAttnModel(config, 
                               encoder_embeddings_matrix, 
                               decoder_embeddings_matrix, 
                               input_word_index, 
                               output_word_index)
# Out:
# [INFO] Building Model ...
# WARNING:tensorflow:From /home/gaurav/.local/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py:430: calling reverse_sequence (from tensorflow.python.ops.array_ops) with seq_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# seq_dim is deprecated, use seq_axis instead
# WARNING:tensorflow:From /home/gaurav/.local/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:454: calling reverse_sequence (from tensorflow.python.ops.array_ops) with batch_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# batch_dim is deprecated, use batch_axis instead
# WARNING:tensorflow:From /home/gaurav/tf-var-attention/ved_varAttn/varAttention_decoder/attention_wrapper.py:1032: calling count_nonzero (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
if config['load_checkpoint'] != 0: 
    checkpoint = config['model_checkpoint_dir'] + str(config['load_checkpoint']) + '.ckpt'
else:
    checkpoint = tf.train.get_checkpoint_state(os.path.dirname('models/checkpoint')).model_checkpoint_path

preds = model.predict(checkpoint, 
                      x_test, 
                      y_test, 
                      true_test, 
                      )
# Out:
# INFO:tensorflow:Restoring parameters from models/var-seq2seq-var-attn-9.ckpt
# BLEU 1 to 4 : 89.02 | 79.34 | 70.22 | 50.91

# %%
count = 100
model.show_output_sentences(preds[:count], 
                            y_test[:count], 
                            input_test[:count], 
                            true_test[:count], 
                            )
# Out:
# Input:      i have always used these for my crvs .
# Actual:     use for crv
# Generated: use for crv
#
# Input:      we were sad when these were replaced by plastic tumblers at costco  we like to use them for hot liquids .
# Actual:     use for hot liquid
# Generated: use for liquid
#
# Input:      for this reason  i would not use it inside to do a large bird - we placed it outside the garage on the concrete .
# Actual:     use for reason
# Generated: use for reason
#
# Input:      no problems after using the toro for over 2 hours .
# Actual:     use toro for hour
# Generated: use toro for hour
#
# Input:      used this product holistically for my terminally ill dog  and i loved it .
# Actual:     use product for ill dog
# Generated: use product for dog
#
# Input:      surefire really made it so that it can be used for tactical purpose .
# Actual:     use for purpose
# Generated: use for purpose
#
# Input:      my husband uses this for light tilling  especially for our vegetable garden .
# Actual:     use for vegetable garden
# Generated: use for tilling garden
#
# Input:      use this for my lawn mower - works as advertised and very easy to install .
# Actual:     use for lawn mower
# Generated: use for mower
#
# Input:      the system attaches to your network easily  set up is simple  it can use your existing home phone wiring  they offer you a second phone number with the inexpensive premium service -lrb- can be used for fax machines -rrb-  voice quality is excellent .
# Actual:     use for machine
# Generated: use for fax machine
#
# Input:      i do n't remember why i was originally shopping fo these  but i realized that i could use them for lots of stuff besides work .
# Actual:     use for lot
# Generated: use for lot
#
# Input:      usually i do most of my major grilling on a gas grill  or use the smoker for bigger meats  but every now and then nothing is better than some meat or veggies cooked over some charcoal -- i just did n't have room on the deck for a large charcoal grill and i 'm not a fan of the big barrel-type charcoal grills  even though they do n't require as big of a footprint as a wide grill.i live just a few miles from the lodge factory in south pittsburg  tn and stumbled across this great little grill one day when i stopped in at their factory outlet store in search of a lid for an old cast iron skillet of theirs .
# Actual:     use smoker for meat
# Generated: use smoker for meat
#
# Input:      note : powder can get clumpy  so mix/shake/blend vigorously to get is smooth!i like to mix it up  so it 's a great flavor to add to almond milk  shakes  or even to use for baking !
# Actual:     use for bake
# Generated: use for purpose
#
# Input:      i use them for my lawn care company and they are durable and save me time and money .
# Actual:     use for care company
# Generated: use for company
#
# Input:      i use a heavier paper for professional use -lrb- business letters and documents -rrb-  but this is great for everything else .
# Actual:     use paper for professional use
# Generated: use paper for use
#
# Input:      we have had to use them for two hurricanes and could not be happier with this product .
# Actual:     use for hurricane
# Generated: use for hurricane
#
# Input:      i love this product and epson seems to be of much higher quality than other printers that i 've used in the past  especially for the price .
# Actual:     use for price
# Generated: use for higher feature
#
# Input:      went from german coffee makers to a bunn finally settling on the hamilton beach two wayuse the pod for one or two cups and use the carafe for guestsenough said !!!
# Actual:     use carafe for guestsenough
# Generated: use carafe for guestsenough
#
# Input:      i can use the dishwasher for the brewing parts .
# Actual:     use dishwasher for part
# Generated: use dishwasher for brewing part
#
# Input:      i 've used hps lights for flowering for a while and this is the lowest price setup i 've ever bought .
# Actual:     use light for while
# Generated: use light for while
#
# Input:      you need to use spray oil for egg beaters.be careful cleaning this thing .
# Actual:     use oil for cleaning
# Generated: use oil for careful cleaning
#
# Input:      i wanted something fast  easy to use with a big enough cup for my morning coffee .
# Actual:     use for morning coffee
# Generated: use for coffee
#
# Input:      back in the day  i would always use a mousepad for my computer mice -- mainly due to the older &#34; rolling ball &#34; technology .
# Actual:     use mousepad for computer mouse
# Generated: use mousepad for mouse
#
# Input:      this 3-pack of paper was just the right size  and it comes in a box that i can use for other things .
# Actual:     use for thing
# Generated: use for other thing
#
# Input:      i use this for everything from cleaning to a burping cloth for my newborn .
# Actual:     use for everything
# Generated: use for everything
#
# Input:      i 've used it for scratch-pizza  lasagna  baked chicken  and streusel-cake already .
# Actual:     use for scratch-pizza
# Generated: use for scratch-pizza
#
# Input:      we relocated and waited 4 nights for our household goods to arrive  so this mattress was used for those 4 nights .
# Actual:     use for night
# Generated: use for night
#
# Input:      i use it regularly for heating water .
# Actual:     use for heating water
# Generated: use for water
#
# Input:      i was not aware of the problem and used my cup for long periods without doing any more then just a quick rinse .
# Actual:     use cup for long period
# Generated: use cup for period
#
# Input:      tube for 1 \ '' flashlight/laser -lrb- ms1m -rrb- using for mossberg 500 .
# Actual:     use for mossberg
# Generated: use for mossberg
#
# Input:      i 've heard they use the same plastic for the international space station and that nasa is studying the material for hovercrafts !
# Actual:     use plastic for space station
# Generated: use plastic for international station
#
# Input:      the led 's a very bright hoping do n't have to use it for sandy ii ever .
# Actual:     use for ii
# Generated: use for ii ii
#
# Input:      you can put a pizza in it  bake cookies and even a roast and the teenagers can still use it for their pizza rolls and chicken nuggets !
# Actual:     use for pizza roll
# Generated: use for roll
#
# Input:      i use this item for my chihuahau -lrb- small dog -rrb- its very helpful for me .
# Actual:     use item for chihuahau
# Generated: use item for chihuahau
#
# Input:      we use it all the time for everything from whipping to kneading dough .
# Actual:     use for everything
# Generated: use for everything
#
# Input:      i use it almost daily for my sciatica issues .
# Actual:     use for issue
# Generated: use for sciatica issue
#
# Input:      i usually use mac brushes for my every day personal use .
# Actual:     use brush for personal use
# Generated: use brush for use
#
# Input:      we have used this coffee maker for a couple of days so far and are highly pleased .
# Actual:     use maker for couple
# Generated: use maker for couple
#
# Input:      the lid is a bit of a pain to clean if you do n't have a dishwasher  but i only use it for water so that is less of a problem for me.i only wish i had gotten the 20 oz version -lrb- did n't realize there was a 20 oz version when i ordered this -rrb- - contigo autoseal west loop stainless steel 20-ounce travel mug with easy-clean lid  stainless steel
# Actual:     use for water
# Generated: use brush for while
#
# Input:      used it for a few jobs around the house and have n't had to re-drill any extra holes yet .
# Actual:     use for job
# Generated: use for job
#
# Input:      i understand that the product is not intended for the face  however i used it for my facial sweating and so far i have not seen any side affect .
# Actual:     use for sweating
# Generated: use for sweating
#
# Input:      it is convenient to use and provides accurate readings for pulse and oxygen .
# Actual:     use reading for pulse
# Generated: use reading for pulse
#
# Input:      a nice improvement over my old grinder that i 'll now use only for spices .
# Actual:     use for spice
# Generated: use for spice
#
# Input:      i use it for a small batch of coffee press mostly .
# Actual:     use for small batch
# Generated: use for batch
#
# Input:      i bought this product because i was looking for something safe to use for ticks on my dog .
# Actual:     use for tick
# Generated: use for tick
#
# Input:      here 's my current thinking : pros - looks great -lrb- i got the silver one -rrb- ; no scratches so far either - keeps my milk very cold ; ca n't confirm whether it would keep that way for the claimed 12 hours since i only have a 45 minute drive - really spill-proof - seems durable so far ; i also read a review in a men 's magazine that this survived a truck driving over itcons - spill-proof means -lrb- 1 -rrb- lid takes a little effort to close and -lrb- 2 -rrb- in order for liquid to come out  you must also push a button ; neither are a big deal but some folks might not like that slight inconvenience - cleaning is not easy -- i use a tube cleaner that i use for my camelbak bladderoveralldespite a few minor cons  i 'm really glad i bought this .
# Actual:     use con for bladderoveralldespite
# Generated: use con for camelbak bladderoveralldespite
#
# Input:      i use this teapot every day for my 1-2 cups of tea .
# Actual:     use teapot for cup
# Generated: use teapot for cup
#
# Input:      total cost $ 1.80 / mon. i then used the 2nd slot for google voice  i have an indiana number there -lrb- fwiw set up a new gmail account to use only for gv -rrb- .
# Actual:     use slot for voice
# Generated: use slot for voice voice
#
# Input:      i use this for utility kinds of stuff and it really is good .
# Actual:     use for kind
# Generated: use for utility kind
#
# Input:      mine used to for random reasons  but plug this in and poof !
# Actual:     use for reason
# Generated: use for random reason
#
# Input:      i 'm using this kitchen scale for food measurements  baking  candle making - and have found several other places it would be useful as well .
# Actual:     use scale for food measurement
# Generated: use scale for food measurement
#
# Input:      i use the lamp for an hour before the time that i would like to be out of bed .
# Actual:     use lamp for hour
# Generated: use lamp for hour
#
# Input:      got this is last week have already used it for a few different things and it works just fine !
# Actual:     use for thing
# Generated: use for thing
#
# Input:      i used them for pulled pork shoulders and worked like a champ !
# Actual:     use for pull shoulder
# Generated: use for shoulder
#
# Input:      we have been using corning ware for a while and found that it was just too heavy and took up too much space in the dishwasher .
# Actual:     use ware for while
# Generated: use ware for while
#
# Input:      i use it for south indian flat breads .
# Actual:     use for south bread
# Generated: use for bread
#
# Input:      it is very easy to use for seniors  and the result is clear and accurate .
# Actual:     use for senior
# Generated: use for senior
#
# Input:      only kidding i am so happy with this product that i bought a second pair one for each of my shops ... shop in bsm table saw and raidal arm and shop in garrage band saw ... i also use it for my garden tractor great product ... sure beats the old one i had ... they dont deflect when i turn my head like the other brand did stayes snug and soundproof ...
# Actual:     use for great product
# Generated: use for product
#
# Input:      i use them for cloth diapers but will use them for years for swimming suits  etc. .
# Actual:     use for diaper
# Generated: use for cloth diaper
#
# Input:      i use so much biofreeze on my neck for neck pain .
# Actual:     use biofreeze for pain
# Generated: use biofreeze for pain
#
# Input:      it is also strong enough to be used for survival and will work for tasks as well .
# Actual:     use for survival
# Generated: use for survival
#
# Input:      i use it for baking  and i 've noticed some differences -lrb- for the better -rrb- in the outcome of some of the breads i bake by using the weight measurements .
# Actual:     use for bake
# Generated: use for bake
#
# Input:      i use it for technical drawing in my architect job .
# Actual:     use for drawing
# Generated: use for drawing
#
# Input:      i received my garcinia cambogia extract and green coffee bean extract together and i 've been using them for weight loss for the last week or so .
# Actual:     use for weight loss
# Generated: use for loss
#
# Input:      i use the peppermint for kitchen-related tasks -lrb- it seems to take on \ `` dish funk \ '' the best -rrb- and the lavender for body wash/shampoo .
# Actual:     use peppermint for task
# Generated: use peppermint for kitchen-related task
#
# Input:      we are using an ooma box and the internet for our service .
# Actual:     use box for service
# Generated: use box for service
#
# Input:      these things are awesome i use them for pretty much everything mainly i use them to tie around my dog collar so i can find them at night they come with a rubber band but i switched that out with velcro to secure to the dog harness better .
# Actual:     use for everything
# Generated: use for everything
#
# Input:      i used it with mineral powder foundation  and it worked wonders with it as well.it can be used for foundation  blush  bronzer  finisher  anything really !
# Actual:     use for foundation
# Generated: use for foundation
#
# Input:      my son has been using it for his math class and says this calculator is fantastic .
# Actual:     use for math class
# Generated: use for math class
#
# Input:      not only for grinding or smoothing soups  we also use this tool for whipping cream .
# Actual:     use tool for cream
# Generated: use tool for whipping cream
#
# Input:      i will say is n't not something i would use for professional use .
# Actual:     use for professional use
# Generated: use for use
#
# Input:      now many of my family members use it for their pain relief .
# Actual:     use for pain relief
# Generated: use for relief
#
# Input:      use these for grilling  nice to have the dexterity .
# Actual:     use for grilling
# Generated: use for grilling
#
# Input:      i use this for normal writing  not drafting per se .
# Actual:     use for writing
# Generated: use for normal writing
#
# Input:      i have a different thermos mug that i use for cold drinks  and am equally impressed .
# Actual:     use for cold drink
# Generated: use for drink
#
# Input:      the roller works well but if you have a chronically very sore back you are going to have to use this every day for an extended period and you still might have to supplement it with physical therapy or therapeutic massage .
# Actual:     use for period
# Generated: use for period
#
# Input:      i ca n't speak to if it will be good for a large business  but as for using it for a small business  it is great .
# Actual:     use for business
# Generated: use for business
#
# Input:      ordered these pens for my son to use for school assignments .
# Actual:     use for assignment
# Generated: use for school assignment
#
# Input:      il ' l be using this on my camping trips as well as for my bug out bag for those just in case moments
# Actual:     use for bug
# Generated: use for bug
#
# Input:      ever dream of loading highlighted documents onto your calculator?i used this calculator for one semester .
# Actual:     use calculator for semester
# Generated: use calculator for semester
#
# Input:      now i will use ooma for a lot of calling and possibly downgrade my cell minutes . -rrb-
# Actual:     use ooma for lot
# Generated: use ooma for lot
#
# Input:      i would n't use it for dense or tall weeds but for anything else it 's awesome !
# Actual:     use for weed
# Generated: use for dense weed
#
# Input:      i use this playpen for my chinchillas .
# Actual:     use playpen for chinchilla
# Generated: use playpen for chinchilla
#
# Input:      i 've used these for my kids xbox controller  my electric shaver  and toys .
# Actual:     use for kid
# Generated: use for kid
#
# Input:      i bought this to use for my ebay business .
# Actual:     use for business
# Generated: use for business
#
# Input:      you can also shave wood from the bark or body of a dry tree  and use that for tinder .
# Actual:     use for tinder
# Generated: use for tinder
#
# Input:      i use a blender for about 30-40 seconds and it mixes and tastes great .
# Actual:     use blender for seconds
# Generated: use blender for seconds
#
# Input:      i have a number of knives i use for home repair  outdoors stuff  and around the house .
# Actual:     use for repair
# Generated: use for repair
#
# Input:      but i find it 's easy enough to move around in the pot without bumping anything and it draws the ingredients in from the sides and bottom.today i used it for a chile colorado recipe that called for processing solid ingredients in a food processor with a little liquid to form a paste  then adding the paste to a pot with the rest of the liquid .
# Actual:     use for recipe
# Generated: use for recipe
#
# Input:      i can continue my exercises at home and also use it for stretching .
# Actual:     use for stretch
# Generated: use for stretch
#
# Input:      i use this for my 16 lb mini beagle .
# Actual:     use for minus beagle
# Generated: use for beagle
#
# Input:      i 've only used it for liquid foundations and it makes me look flawless .
# Actual:     use for foundation
# Generated: use for liquid foundation
#
# Input:      the children also love using them for dance party with all the house lights off .
# Actual:     use for dance party
# Generated: use for party
#
# Input:      i 've had this smart stick for about a month now and usually use it a few times each day for a juice/vegetable detox diet that i have been going on .
# Actual:     use for detox diet
# Generated: use for diet
#
# Input:      i 've intoduced it to several of my friends and they now stop by just to use the back buddy for a couple minutes .
# Actual:     use buddy for couple minute
# Generated: use buddy for several hour
#
# Input:      i would use these pens for your writing and there good looks .
# Actual:     use pen for writing
# Generated: use pen for writing
#
# Input:      i used this for my first 16 hours smoked pork shoulder and it shredded it to perfection .
# Actual:     use for first hour
# Generated: use for hour
#
# Input:      this is a very good knife comes razor sharp out of the box just like the other buck knives i purchased in the past  is made in the usa and is a very good looking knife  it is medium size best to use it with the leather sheat that came with it i recommend it to use it for daily tasks and if something happen to the blade it comes with a lifetime warranty
# Actual:     use for task
# Generated: use for task
#
# Input:      i use de for every pest control problem i have now -lrb- including in my garden -rrb- and i 'm amazed at what this stuff can do !
# Actual:     use de for problem
# Generated: use de for problem
#
# Input:      this essential oil is used for calming and stress relief .
# Actual:     use for relief
# Generated: use for calming relief
#
# Input:      i have been using this product for a little bit over a month and so far i am satisfied .
# Actual:     use product for little bit
# Generated: use product for little guy

# %%
model.get_diversity_metrics(checkpoint, x_test, y_test)
# Out:
# INFO:tensorflow:Restoring parameters from models/var-seq2seq-var-attn-9.ckpt
# 100%|██████████| 3/3 [11:24<00:00, 229.09s/it]
# Entropy = 1.235 | Distinct-1 = 0.102 | Distinct-2 = 0.106
