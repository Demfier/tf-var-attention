# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

import sys

if not '../' in sys.path: sys.path.append('../')

import pandas as pd

from utils import data_utils
from model_config import config
from ved_varAttn import VarSeq2SeqVarAttnModel
# Out:
# Using TensorFlow backend.

# %%
if config['experiment'] == 'qgen':
    print('[INFO] Preparing data for experiment: {}'.format(config['experiment']))
    train_data = pd.read_csv(config['data_dir'] + 'df_qgen_train.csv')
    val_data = pd.read_csv(config['data_dir'] + 'df_qgen_val.csv')
    test_data = pd.read_csv(config['data_dir'] + 'df_qgen_test.csv')
    input_sentences = pd.concat([train_data['answer'], val_data['answer'], test_data['answer']])
    output_sentences = pd.concat([train_data['question'], val_data['question'], test_data['question']])
    true_test = test_data['question']
    input_test = test_data['answer']
    filters = '!"#$%&()*+,./:;<=>?@[\\]^`{|}~\t\n'
    w2v_path = config['w2v_dir'] + 'w2vmodel_qgen.pkl'
    
elif config['experiment'] == 'dialogue':
    train_data = pd.read_csv(config['data_dir'] + 'df_dialogue_train.csv')
    val_data = pd.read_csv(config['data_dir'] + 'df_dialogue_val.csv')
    test_data = pd.read_csv(config['data_dir'] + 'df_dialogue_test.csv')
    input_sentences = pd.concat([train_data['line'], val_data['line'], test_data['line']])
    output_sentences = pd.concat([train_data['reply'], val_data['reply'], test_data['reply']])
    true_test = test_data['reply']
    input_test = test_data['line']
    filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
    w2v_path = config['w2v_dir'] + 'w2vmodel_dialogue.pkl'

elif config['experiment'] == 'arc':
        train_data = pd.read_csv(config['data_dir'] + 'df_arc_train.csv')
        val_data = pd.read_csv(config['data_dir'] + 'df_arc_val.csv')
        test_data = pd.read_csv(config['data_dir'] + 'df_arc_test.csv')
        input_sentences = pd.concat([train_data['ProductSent'],
                                    val_data['ProductSent'],
                                    test_data['ProductSent']])
        output_sentences = pd.concat([train_data['ProductPhrase'],
                                      val_data['ProductPhrase'],
                                      test_data['ProductPhrase']])
        true_test = test_data['ProductPhrase']
        input_test = test_data['ProductSent']
        filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
        w2v_path = config['w2v_dir'] + 'w2vmodel_arc.pkl'

else:
    print('Invalid experiment name specified!')

# %%
print('[INFO] Tokenizing input and output sequences')
x, input_word_index = data_utils.tokenize_sequence(input_sentences, 
                                                                      filters, 
                                                                      config['encoder_num_tokens'], 
                                                                      config['encoder_vocab'])

y, output_word_index = data_utils.tokenize_sequence(output_sentences, 
                                                                        filters, 
                                                                        config['decoder_num_tokens'], 
                                                                        config['decoder_vocab'])

print('[INFO] Split data into train-validation-test sets')
x_train, y_train, x_val, y_val, x_test, y_test = data_utils.create_data_split(x, 
                                                                              y, 
                                                                              config['experiment'])

encoder_embeddings_matrix = data_utils.create_embedding_matrix(input_word_index, 
                                                               config['embedding_size'], 
                                                               w2v_path)

decoder_embeddings_matrix = data_utils.create_embedding_matrix(output_word_index, 
                                                               config['embedding_size'], 
                                                               w2v_path)

# Re-calculate the vocab size based on the word_idx dictionary
config['encoder_vocab'] = len(input_word_index)
config['decoder_vocab'] = len(output_word_index)
# Out:
# [INFO] Tokenizing input and output sequences
# [INFO] Split data into train-validation-test sets

# %%
model = VarSeq2SeqVarAttnModel(config, 
                               encoder_embeddings_matrix, 
                               decoder_embeddings_matrix, 
                               input_word_index, 
                               output_word_index)
# Out:
# [INFO] Building Model ...
# WARNING:tensorflow:From /home/gaurav/.local/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py:430: calling reverse_sequence (from tensorflow.python.ops.array_ops) with seq_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# seq_dim is deprecated, use seq_axis instead
# WARNING:tensorflow:From /home/gaurav/.local/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:454: calling reverse_sequence (from tensorflow.python.ops.array_ops) with batch_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# batch_dim is deprecated, use batch_axis instead
# WARNING:tensorflow:From /home/gaurav/tf-var-attention/ved_varAttn/varAttention_decoder/attention_wrapper.py:1032: calling count_nonzero (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
if config['load_checkpoint'] != 0: 
    checkpoint = config['model_checkpoint_dir'] + str(config['load_checkpoint']) + '.ckpt'
else:
    checkpoint = tf.train.get_checkpoint_state(os.path.dirname('models/checkpoint')).model_checkpoint_path

preds = model.predict(checkpoint, 
                      x_test, 
                      y_test, 
                      true_test, 
                      )
# Out:
# INFO:tensorflow:Restoring parameters from models/var-seq2seq-var-attn-9.ckpt
# BLEU 1 to 4 : 88.31 | 77.83 | 68.12 | 49.15

# %%
count = 100
model.show_output_sentences(preds[:count], 
                            y_test[:count], 
                            input_test[:count], 
                            true_test[:count], 
                            )
# Out:
# Input:      I have been using it almost every day for over 3 months and plan to use it for many more.I highly recommend this little blender .
# Actual:     use for many recommend
# Generated: use for recommend recommend
#
# Input:      For my movie-style buttered popcorn  I use 1/4 cup of white popcorn  1/3 stick of salted butter  and fine-grainedPopcorn Saltto taste before popping .
# Actual:     use cup for movie-style popcorn
# Generated: use cup for buttered popcorn
#
# Input:      The feed mechanism is not gentle enough for pictures  either  so you 'd want to use the included carrier sheet for any photos you really cared about  which defeats the document feeder aspect of the scanner.The software has flashes of brilliance and moments of stupidity .
# Actual:     use sheet for photo
# Generated: use for photo
#
# Input:      I 've only been using the Mini ` Zinger for a couple of days  but I have to say it has certainly helped to deter the wasps/yellow jackets .
# Actual:     use Zinger for couple
# Generated: use zinger for couple
#
# Input:      Make sure you use the correct amount of water for cup size and not more  or it will spill over and ruin your cup .
# Actual:     use amount for size
# Generated: use amount for size
#
# Input:      I 've used 3/4 a bag for a 5 room 500square foot apartment .
# Actual:     use bag for apartment
# Generated: use bag for room apartment
#
# Input:      I use the vac for the stairs in my two story house .
# Actual:     use vac for stair
# Generated: use vac for stair
#
# Input:      I used this for my -LRB- 9 -RRB- year old daughters finger sucking .
# Actual:     use for old sucking
# Generated: use for sucking
#
# Input:      I 'm a photographer and use a lot of AA batteries for my flashes and wireless triggers .
# Actual:     use lot for flash
# Generated: use lot for flash
#
# Input:      Yes it is loud but it does n't bother me since I only use it for a few minutes at a time .
# Actual:     use for few minute
# Generated: use for minute
#
# Input:      So I know good bread when I see/taste it!I 've used it for white  whole wheat and raisin breads and love the fast bake cycle .
# Actual:     use for wheat
# Generated: use for white wheat
#
# Input:      Best product I 've ever used for auto interior .
# Actual:     use for auto interior
# Generated: use for interior
#
# Input:      ... first time used for 8 hours ... worked flawlessly ... round two today after 4 &#34; rain to bring pool level down ... very little supervision needed .
# Actual:     use for hour
# Generated: use for hour
#
# Input:      I use it for a few dental xrays  now and then an as a general purpose scanner .
# Actual:     use for few xray
# Generated: use for xray
#
# Input:      I am looking forward to using it this summer for fish fry too .
# Actual:     use for fry
# Generated: use for fry
#
# Input:      I sit  relaxed in the same chair  using the same arm at the same time of day for consistency .
# Actual:     use arm for consistency
# Generated: use arm for consistency
#
# Input:      I often use the vertical steam for my rayon tops and it quickly erases the wrinkles with a few blasts of steam .
# Actual:     use steam for top
# Generated: use steam for top
#
# Input:      I use this for many different games such as Borderlands  Battlefield and Skyrim .
# Actual:     use for different game
# Generated: use for game
#
# Input:      I bought these for my husband to use shred smoked meats for sandwiches .
# Actual:     use meat for sandwich
# Generated: use meat for sandwich
#
# Input:      I 'm not sure I 'll ever use all the different light options  but I use it for close-up craft work  and it 's a wonderful brilliant light .
# Actual:     use for craft work
# Generated: use for close-up work
#
# Input:      The Tidy Cats Breeze litter system is a simple system to set up and use for multiple cats .
# Actual:     use for multiple cat
# Generated: use for multiple cat
#
# Input:      I use the hot water for oatmeal  ramen  mac & cheese ... .
# Actual:     use water for oatmeal
# Generated: use water for oatmeal
#
# Input:      I have an old  broken fridge in my basement that I use for beer fermentation during the winter .
# Actual:     use for beer fermentation
# Generated: use for fermentation
#
# Input:      I 've used this for scanning photographs  receipts and a number of other miscellaneous items .
# Actual:     use for scanning photograph
# Generated: use for scanning photograph
#
# Input:      I purchased this one and must say that it is the most comfortable of the three I bought and I use it for my office chair .
# Actual:     use for office chair
# Generated: use for chair
#
# Input:      I use it for everything  and it has never failed me .
# Actual:     use for everything
# Generated: use for everything
#
# Input:      I may use these for map lights as well -LRB- not sure what bulbs those use on my car -RRB- .
# Actual:     use for map light
# Generated: use for light
#
# Input:      It is used mainly for quick pick-ups and to clean the kitchen floor between scrubbings .
# Actual:     use for quick pick-up
# Generated: use for pick-up
#
# Input:      i use it for first-person shooters  mmos  mobas  basically everything .
# Actual:     use for shooter
# Generated: use for shooter
#
# Input:      I originally started using it almost 4 years ago for cloth diapering and then on my kids ' clothes because it was mild .
# Actual:     use for cloth diapering
# Generated: use for diapering
#
# Input:      I use mine for a multi cat home .
# Actual:     use mine for cat home
# Generated: use mine for home
#
# Input:      this words great and I have n't even tried to use any of its features.Tip for all Wireless Router purchasers : buy a small fan to put with whatever router you buy .
# Actual:     use for purchaser
# Generated: use for purchaser
#
# Input:      We simply cut an opening in the divider for one end to be used for potty  other end leaving much more room for sleeping and play.Works perfectly and saved a bunch of money as it is the same thing in the end .
# Actual:     use for potty
# Generated: use for potty
#
# Input:      Definitely get the separate filter - you can use it for your own coffee beans OR loose leaf tea !
# Actual:     use for coffee bean
# Generated: use for own bean
#
# Input:      I have been holding off on purchasing a flat iron because : 1 -RRB- all the really high quality ones I was looking at in stores were only good for one voltage or another  and 2 -RRB- I worried about damage to my hair.I 'm happy to say that my new HSI Professional iron does a great job smoothing my hair -LRB- I also use it for corkscrew curls -RRB- without damage  and so far it 's been working great no matter what the power source !
# Actual:     use for corkscrew curl
# Generated: use for curl
#
# Input:      Used them for an extended period of time during a power outage .
# Actual:     use for period
# Generated: use for extended period
#
# Input:      sitting in the trunk.battery life had not been reduced still works.you can use for backup battery for small electronic and jumping car battery .
# Actual:     use for battery
# Generated: use for battery
#
# Input:      The dotting tools are perfect to use for nice  neat  round circles .
# Actual:     use for round circle
# Generated: use for nice circle
#
# Input:      Successfully used in Arizona at night for scorpion hunting .
# Actual:     use for scorpion hunting
# Generated: use for hunting
#
# Input:      I usually buy the big container of this as I use it for a few things.FACE MASK : Works amazing mixed with apple cider vinegar -LRB- ACV -RRB- until a thick consistency .
# Actual:     use for few MASK
# Generated: use for mask
#
# Input:      I have used Penetrex for a couple of years now .
# Actual:     use Penetrex for couple
# Generated: use penetrex for couple
#
# Input:      I use it for google voice and just dumped my landline .
# Actual:     use for voice
# Generated: use for google voice
#
# Input:      I frequently use the scanner and copier for recipes and knitting patterns  and the detail is always very sharp .
# Actual:     use scanner for recipe
# Generated: use scanner for recipe
#
# Input:      I use this oil for general softening of body skin AND around nails and cuticles .
# Actual:     use oil for general softening
# Generated: use oil for general softening
#
# Input:      We will be using these pills for life !
# Actual:     use pill for life
# Generated: use pill for life
#
# Input:      This blower is the most quiet and powerful blower I 've ever used except for certain Stihl models with their very high prices .
# Actual:     use except for certain model
# Generated: use except for model
#
# Input:      I bought this vacuum one month ago to use for spot cleaning so I would n't have to get out the big one for every little thing  like spilled flour on the kitchen area rugs .
# Actual:     use for cleaning
# Generated: use for spot cleaning
#
# Input:      I keep it with me everywhere I go  and have even used it for coffee .
# Actual:     use for coffee
# Generated: use for coffee
#
# Input:      Have used to shred chicken for casseroles too .
# Actual:     use for casserole
# Generated: use for casserole
#
# Input:      you could use the f80 for almost anything its versatile but i love this for liquid foundation .
# Actual:     use f80 for anything
# Generated: use f80 for anything
#
# Input:      I recommend checking out some videos online of splitting in action  to get the idea of how to be comfortable with using this style of ax for splitting wood ; The Europeans are especially enjoyable to watch .
# Actual:     use style for wood
# Generated: use style for splitting wood
#
# Input:      You have the control to focus the beam to something that can shine across your yard  or open it up and use it for a more general light inside .
# Actual:     use for light
# Generated: use for light
#
# Input:      The headset is smaller than cheap muffs I was using for target practice and more comfortable .
# Actual:     use for target practice
# Generated: use for practice
#
# Input:      It blends better than a blender and the convenience of drinking right out of the container that is used for blending is perfect .
# Actual:     use for blend
# Generated: use for blend
#
# Input:      Most of my pain is now gone and I can use my right arm and shoulder for most tasks while still avoiding heavy lifting or extreme reaching .
# Actual:     use arm for task
# Generated: use arm for most task
#
# Input:      We found a scale to use for life !
# Actual:     use for life
# Generated: use for life
#
# Input:      I only use it for my bed side gun  so it 's not used everyday to test how it would hold up to rough use .
# Actual:     use for gun
# Generated: use for gun
#
# Input:      I use the mat for general exercises and also for my yoga routine .
# Actual:     use mat for general exercise
# Generated: use mat for general exercise
#
# Input:      I ca n't speak to the accuracy of the body fat % but I will say that I use it mostly for consistency .
# Actual:     use for consistency
# Generated: use for consistency
#
# Input:      I rarely use it for hot liquids -LRB- I do n't drink that many  I guess -RRB-  but it does a great job of keeping cool ones cool even on the warmest of days .
# Actual:     use for liquid
# Generated: use for hot liquid
#
# Input:      I think it 's a great way for them to realize that they can use their front paws for more than just walking .
# Actual:     use paw for walk
# Generated: use paw for walk mail
#
# Input:      May as well leave on in there when I 'm not using it for other activities .
# Actual:     use for activity
# Generated: use for activity
#
# Input:      The larger wheel and the retracting feature make it a good peice of equipment to use for your core workouts .
# Actual:     use for core workout
# Generated: use for workout
#
# Input:      So after being absolutely thrilled with my Seville 3 tier iron shoe utility rack -LRB- which I 've actually use for shoes for about 3 years now -RRB-  I decided to get 2 of the wood composite racks and use them for bathroom storage - I figured that if the shoe racks can withstand wet shoes on them  they probably could take on some amount of moisture from being in the bathroom .
# Actual:     use for storage
# Generated: use for bathroom storage
#
# Input:      Easy to use and the connection can be used for the electric vest .
# Actual:     use for vest
# Generated: use for vest
#
# Input:      I use it for a security net .
# Actual:     use for net
# Generated: use for security net
#
# Input:      Everyone can do math  but this thing is more than that.you can use this calculator for scuba diving  for para sailing  this thing can solve things i did n't know had to be solved.If you read your manuals carefully and practice you can be a TI Nspire MASTER  in no time  also a math master  a chemistry master  and whatever you feel the need to masterfy.Anyway Great product  more than expected  and remember do n't leave this baby at home on your graduation day .
# Actual:     use calculator for diving
# Generated: use calculator for para sailing
#
# Input:      OCR works very well -- and works no matter which orientation is used for the paper feeding .
# Actual:     use for paper feeding
# Generated: use for paper feeding
#
# Input:      It is large enough that I can use it for my needs but also not too large so that it does n't fit on my desk .
# Actual:     use for need
# Generated: use for need
#
# Input:      I 've decided to never use another product for laundry but Charlie 's .
# Actual:     use product for laundry
# Generated: use product for laundry
#
# Input:      I do recommend using a quality paper for best results .
# Actual:     use paper for result
# Generated: use paper for result
#
# Input:      Used it for a beach trip and it was perfect !
# Actual:     use for trip
# Generated: use for beach trip
#
# Input:      We 've been using them for obedience and scent training  for teeth brushing and nail clipping time  and for recall when we walk off leash .
# Actual:     use for recall
# Generated: use for obedience
#
# Input:      This is a 3 pack of Roll On Bio Freeze.I use it almost every day for my back ... I am waiting for back surgery and I can not afford to be doped up on narcotics all day.This will provide a way to relieve that ache without getting it all over your hands.I keep one in my backpack at all times !!
# Actual:     use for back
# Generated: use for wheel
#
# Input:      I use it for home use  but I use it pretty much everyday .
# Actual:     use for use
# Generated: use for home use
#
# Input:      got this carrier to use in my car for my GS pup.He seemed lost at first since it was so much bigger .
# Actual:     use for gs pup.he
# Generated: use for gs pup.he
#
# Input:      I have been using flushable wipes for my family for a while and this has allowed me to replace purchasing those costly wipes and exclusively use this .
# Actual:     use wipe for while
# Generated: use wipe for family
#
# Input:      I use it in my Dodge pickup that I use for snow plowing .
# Actual:     use for snow plowing
# Generated: use for snow plowing
#
# Input:      The easiest thing to use for smoothies and blending soup in the pot .
# Actual:     use for smoothie
# Generated: use for smoothie
#
# Input:      They also appear to be very sturdy unless you are planning to use them for a small horse :-RRB-
# Actual:     use for :-rrb-
# Generated: use for horse -rrb-
#
# Input:      I also started using this detergent for baby clothes and cloth diaper but began using it for all my laundry because of skin sensitivities I have to the residues left by other detergents .
# Actual:     use detergent for clothes
# Generated: use detergent for baby clothes
#
# Input:      Our old one we use for our storage bin .
# Actual:     use for storage bin
# Generated: use for bin
#
# Input:      I like it much better than Sonicare  which I had been using for many years.It fits over and around each tooth and probably does a better job .
# Actual:     use for many fit
# Generated: use for fit
#
# Input:      After initially using this for our cloth diapers and a regular free and clear for the rest of our clothes  we 've switched to this exclusively .
# Actual:     use for cloth diaper
# Generated: use for diaper
#
# Input:      I use them for my dance class .
# Actual:     use for class
# Generated: use for dance class
#
# Input:      Not because the other set wore out but because I use them for so many things that it would just be easier to have 2 sets .
# Actual:     use for thing
# Generated: use for thing
#
# Input:      I have been using cosequin for my rot ever since he had hip surgery and it sure helps him move better .
# Actual:     use cosequin for rot
# Generated: use cosequin for rot
#
# Input:      We use these for in home learning tools and flash cards for a preschooler .
# Actual:     use for preschooler
# Generated: use for preschooler
#
# Input:      Using this for outside x ` mas lights and its just awesome !
# Actual:     use for x
# Generated: use for x x
#
# Input:      In fact  we used an Eatsmart scale at my office for our weight loss challenge.Pros : InexpensiveAccurate readingsBack-lit displayCons : None
# Actual:     use scale for weight challenge.pros
# Generated: use scale for challenge.pros challenge.pros
#
# Input:      You can choose to use the one-minute Massage mode on its own or tack on the end of the normal brushing mode for a three-minute session -LRB- Gum Care -RRB- .
# Actual:     use mode for three-minute session
# Generated: use mode for three-minute session
#
# Input:      Used daily  I 've just cleaned it once and it did n't have a lot of scale or coffee stain  so its good material.Haven ' t used it for cold beverages  so I can say about that  especially as I have some other product I use for cold drinks.I was n't sure if it was worth the money  but for me it was .
# Actual:     use for beverage
# Generated: use for drinks.i
#
# Input:      This tool has helped the tight parts in my shoulders feel much better and helped release my strained neck.I like the knobs on the one curved end that can be used for the back of your neck .
# Actual:     use for back
# Generated: use for back
#
# Input:      The height is just right to bring the computer screen to eye-level which is more ergonomic  and the tilt makes it comfortable to type with the built-in keyboard or use the trackpad for brief tasks .
# Actual:     use trackpad for brief task
# Generated: use trackpad for task
#
# Input:      I use it for my back .
# Actual:     use for back
# Generated: use for back
#
# Input:      I hate to admit that I have still been using contact paper for my laminating needs .
# Actual:     use paper for laminating need
# Generated: use paper for laminating need
#
# Input:      I 've decided to use paracord for the possible zombie apocalypse !
# Actual:     use paracord for possible apocalypse
# Generated: use paracord for zombie apocalypse
#
# Input:      We also use it for soups stews and anything else one might think of cooking in the kitchen .
# Actual:     use for soup stew
# Generated: use for soup
#
# Input:      I typically use the flawless face brush or the kabuki brush for full coverage to cover up blemishes .
# Actual:     use brush for full coverage
# Generated: use brush for coverage
#
# Input:      This one is a keeper!One set of Batteries has been used for around 20 hours so far and they are still producing usable light.Not as bright as when bran new  but very usable.The light has been used for all kinds of hikes  walks  and two power outages and it just works.The kids love it too.They love walking outside after dark with the lantern for light.Or hanging it on the swing set and swinging after dark with friends.Or taking it up into the treehouse after dark and playing.It has been dropped  several times from various heights  with just a couple of scuffs.And it has worked no matter what .
# Actual:     use for kind
# Generated: use for hour

# %%
model.get_diversity_metrics(checkpoint, x_test, y_test)
# Out:
# INFO:tensorflow:Restoring parameters from models/var-seq2seq-var-attn-9.ckpt
# 100%|██████████| 3/3 [11:27<00:00, 229.72s/it]
# Entropy = 1.241 | Distinct-1 = 0.102 | Distinct-2 = 0.106
