# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

import sys

if not '../' in sys.path: sys.path.append('../')

import pandas as pd

from utils import data_utils
from model_config import config
from ved_varAttn import VarSeq2SeqVarAttnModel
# Out:
# Using TensorFlow backend.

# %%
if config['experiment'] == 'qgen':
    print('[INFO] Preparing data for experiment: {}'.format(config['experiment']))
    train_data = pd.read_csv(config['data_dir'] + 'df_qgen_train.csv')
    val_data = pd.read_csv(config['data_dir'] + 'df_qgen_val.csv')
    test_data = pd.read_csv(config['data_dir'] + 'df_qgen_test.csv')
    input_sentences = pd.concat([train_data['answer'], val_data['answer'], test_data['answer']])
    output_sentences = pd.concat([train_data['question'], val_data['question'], test_data['question']])
    true_test = test_data['question']
    input_test = test_data['answer']
    filters = '!"#$%&()*+,./:;<=>?@[\\]^`{|}~\t\n'
    w2v_path = config['w2v_dir'] + 'w2vmodel_qgen.pkl'
    
elif config['experiment'] == 'dialogue':
    train_data = pd.read_csv(config['data_dir'] + 'df_dialogue_train.csv')
    val_data = pd.read_csv(config['data_dir'] + 'df_dialogue_val.csv')
    test_data = pd.read_csv(config['data_dir'] + 'df_dialogue_test.csv')
    input_sentences = pd.concat([train_data['line'], val_data['line'], test_data['line']])
    output_sentences = pd.concat([train_data['reply'], val_data['reply'], test_data['reply']])
    true_test = test_data['reply']
    input_test = test_data['line']
    filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
    w2v_path = config['w2v_dir'] + 'w2vmodel_dialogue.pkl'

elif config['experiment'] == 'arc':
        train_data = pd.read_csv(config['data_dir'] + 'df_arc_train.csv')
        val_data = pd.read_csv(config['data_dir'] + 'df_arc_val.csv')
        test_data = pd.read_csv(config['data_dir'] + 'df_arc_test.csv')
        input_sentences = pd.concat([train_data['ProductSent'],
                                    val_data['ProductSent'],
                                    test_data['ProductSent']])
        output_sentences = pd.concat([train_data['ProductPhrase'],
                                      val_data['ProductPhrase'],
                                      test_data['ProductPhrase']])
        true_test = test_data['ProductPhrase']
        input_test = test_data['ProductPhrase']
        filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
        w2v_path = config['w2v_dir'] + 'w2vmodel_arc.pkl'

else:
    print('Invalid experiment name specified!')

# %%
print('[INFO] Tokenizing input and output sequences')
x, input_word_index = data_utils.tokenize_sequence(input_sentences, 
                                                                      filters, 
                                                                      config['encoder_num_tokens'], 
                                                                      config['encoder_vocab'])

y, output_word_index = data_utils.tokenize_sequence(output_sentences, 
                                                                        filters, 
                                                                        config['decoder_num_tokens'], 
                                                                        config['decoder_vocab'])

print('[INFO] Split data into train-validation-test sets')
x_train, y_train, x_val, y_val, x_test, y_test = data_utils.create_data_split(x, 
                                                                              y, 
                                                                              config['experiment'])

encoder_embeddings_matrix = data_utils.create_embedding_matrix(input_word_index, 
                                                               config['embedding_size'], 
                                                               w2v_path)

decoder_embeddings_matrix = data_utils.create_embedding_matrix(output_word_index, 
                                                               config['embedding_size'], 
                                                               w2v_path)

# Re-calculate the vocab size based on the word_idx dictionary
config['encoder_vocab'] = len(input_word_index)
config['decoder_vocab'] = len(output_word_index)
# Out:
# [INFO] Tokenizing input and output sequences
# [INFO] Split data into train-validation-test sets

# %%
model = VarSeq2SeqVarAttnModel(config, 
                               encoder_embeddings_matrix, 
                               decoder_embeddings_matrix, 
                               input_word_index, 
                               output_word_index)
# Out:
# [INFO] Building Model ...
# WARNING:tensorflow:From /home/gaurav/.local/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py:430: calling reverse_sequence (from tensorflow.python.ops.array_ops) with seq_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# seq_dim is deprecated, use seq_axis instead
# WARNING:tensorflow:From /home/gaurav/.local/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:454: calling reverse_sequence (from tensorflow.python.ops.array_ops) with batch_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# batch_dim is deprecated, use batch_axis instead
# WARNING:tensorflow:From /home/gaurav/tf-var-attention/ved_varAttn/varAttention_decoder/attention_wrapper.py:1032: calling count_nonzero (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
if config['load_checkpoint'] != 0: 
    checkpoint = config['model_checkpoint_dir'] + str(config['load_checkpoint']) + '.ckpt'
else:
    checkpoint = tf.train.get_checkpoint_state(os.path.dirname('models/checkpoint')).model_checkpoint_path

preds = model.predict(checkpoint, 
                      x_test, 
                      y_test, 
                      true_test, 
                      )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d2679f17df51> in <module>()
#       7                       x_test,
#       8                       y_test,
# ----> 9                       true_test,
#      10                       )
#
# NameError: name 'true_test' is not defined

# %%
count = 100
model.show_output_sentences(preds[:count], 
                            y_test[:count], 
                            input_test[:count], 
                            true_test[:count], 
                            )
# Out:
# Input:      fantasia released as her coronation single i believe a song co written by season one finalist tamyra gray and degarmo released dreams
# Actual:     what was the first song released by diana degarmo after coming in second on american idol ?
# Generated: what was the name of queen s song ?
#
# Input:      he increased the faculty by more than 500 professors the academic quality of the student body has improved dramatically with the average sat score rising from 1240 to 1360 the number of minority students more than doubled the endowment grew from 350 million to more than 3 billion the annual operating budget rose from 177 million to more than 650 million and annual research funding improved from 15 million to more than 70 million
# Actual:     when malloy reached the end of his time as president how much annuals funding for research did notre dame have ?
# Generated: how many professors did professors make up the average score ?
#
# Input:      together with the national marine aquarium the sir alister hardy foundation for ocean sciences plymouth university s marine institute and the diving diseases research centre these marine related organisations form the plymouth marine sciences partnership
# Actual:     what is the name of the aquarium present in plymouth ?
# Generated: what is the name of the name of the world s marine marine grouping ?
#
# Input:      on december 3 2013 adidas officially confirmed a new shoe collaboration deal with west
# Actual:     how many seasons of clothing did kanye release ?
# Generated: when did the 2013 version of the new haven new line connect ?
#
# Input:      average annual rainfall is around 980 millimetres 39 in
# Actual:     about how many inches of rain fall on plymouth every year ?
# Generated: what is average annual rainfall in tucson ?
#
# Input:      the doctrine of pratītyasamutpāda sanskrit pali paticcasamuppāda tibetan wylie rten cing brel bar byung ba chinese 緣起 is an important part of buddhist metaphysics
# Actual:     the doctrine of pratityasumatupada is a important part of what type of metaphysics ?
# Generated: what is the name of the sanskrit sanskrit ?
#
# Input:      the chemical structure of penicillin was determined by dorothy crowfoot hodgkin in 1945
# Actual:     who discovered the chemical structure of penicillin ?
# Generated: who was determined by the atomic of zinc ?
#
# Input:      its ad prices reached a peak in season seven at 737000
# Actual:     how much did advertisers spend for a 30 second ad spot during american idol in its seventh season ?
# Generated: how much did the land prices reach in the year ?
#
# Input:      in the 1950s and 1960s dogs were kept outside more often than they tend to be today using the expression in the doghouse to describe exclusion from the group signifies the distance between the doghouse and the home and were still primarily functional acting as a guard children s playmate or walking companion
# Actual:     in the 1950s and 1960s most dogs where kept where ?
# Generated: what is the term for the word that are primarily used to describe the word angiosperm ?
#
# Input:      in 2003 beyoncé starred opposite cuba gooding jr in the musical comedy the fighting temptations as lilly a single mother whom gooding s character falls in love with
# Actual:     what song did beyoncé release as the lead single from the fighting tempations ?
# Generated: what was the name of the song that was featured in the song ?
#
# Input:      major banks suffered losses from aaa rated created by financial engineering which creates apparently risk free assets out of high risk collateral that required less capital according to basel ii
# Actual:     what term describes creating risk free assets out of high risk collateral ?
# Generated: what was the main financial force in the 1980s ?
#
# Input:      the winner of the finals show received a dream ticket that granted them front of the line privileges at any future american idol audition
# Actual:     what did the winner win ?
# Generated: what did the winner of the winner show ?
#
# Input:      the essay from which aims of education derived its name was delivered as an address in 1916 when whitehead was president of the london branch of the mathematical association
# Actual:     what is the origin of the title of the book ?
# Generated: when was the essay of education derived from the book of education ?
#
# Input:      since the work of franz boas and bronisław malinowski in the late 19th and early 20th centuries social anthropology in great britain and cultural anthropology in the us have been distinguished from other social sciences by its emphasis on cross cultural comparisons long term in depth examination of context and the importance it places on participant observation or experiential immersion in the area of research
# Actual:     what has cultural anthropology distinguished itself from other social sciences by emphasizing ?
# Generated: what was the name of the modern movement in the united states ?
#
# Input:      works published since 1857 have received alternative catalogue designations instead of opus numbers
# Actual:     pieces published after what year stopped receiving opus numbers ?
# Generated: what kind of programming did works have on the sanskrit ?
#
# Input:      the first year of studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major
# Actual:     what was created at notre dame in 1962 to assist first year students ?
# Generated: when was the first year of the first year of testing program established ?
#
# Input:      white then commits suicide
# Actual:     how does white deal with his condition ?
# Generated: who was the person clinton clinton ?
#
# Input:      commercial relationships quickly grew between the inland bantu kingdoms and european merchants who traded various commodities manufactured goods and people captured from the hinterlands
# Actual:     what did european traders exchange with bantu people ?
# Generated: what did the settlers of the european settlers capture ?
#
# Input:      sergei diaghilev commissioned additional orchestrations from stravinsky anatoly lyadov sergei taneyev and nikolai tcherepnin for later productions which used the title les sylphides
# Actual:     sergei diaghilev obtained additional orchestrations for subsequent productions using which title ?
# Generated: what was the title of the title of the title of the title of the title of the title of ?
#
# Input:      her singing talent was discovered when dance instructor darlette johnson began humming a song and she finished it able to hit the high pitched notes
# Actual:     who was the first person to notice beyonce s singing ability ?
# Generated: when did madonna s dance dance ?
#
# Input:      in february 2015 over fifteen hundred extras were hired for the pre title sequence set in mexico though they were duplicated in the film giving the effect of around ten thousand extras
# Actual:     when was the opening scene of spectre filmed ?
# Generated: how many replays were offered for the mayan title ?
#
# Input:      bruce matthews notes that there is no cohesive presentation of karma in the sutta pitaka which may mean that the doctrine was incidental to the main perspective of early buddhist soteriology
# Actual:     bronkhurst says that buddha had a view of what much different then current day ?
# Generated: what does bruce bruce write about ?
#
# Input:      he appeared on larry king live on november 20 2007 but left before speaking
# Actual:     what talk show did the doctor who performed donda west s plastic surgery appear on ?
# Generated: when did kerry appear on the day ?
#
# Input:      wings represent the grouping of various squadrons both operational and support under a single tactical commander reporting to the operational commander and vary in size from several hundred personnel to several thousand
# Actual:     who reports to the operational commander about the wings ?
# Generated: what do members of the us air force and support ?
#
# Input:      in 1625 construction was started on a citadel and a fort amsterdam on manhattan island later called new amsterdam nieuw amsterdam
# Actual:     on what island was fort amsterdam built ?
# Generated: when was the construction of the fort built ?
#
# Input:      on the same day the chengdu military region command dispatched 50000 troops and armed police to help with disaster relief work in wenchuan county
# Actual:     how many troops were dispatched by the chengdu military ?
# Generated: how many troops did the chengdu military fleet have ?
#
# Input:      this tour was suggested to him by his scottish pupil jane stirling and her elder sister
# Actual:     who provided the majority of funds for his concert tour in london ?
# Generated: who was the name of the queen s sister ?
#
# Input:      novice monks use the ten precepts which are the basic precepts for monastics
# Actual:     how many basic precepts are there for monastics ?
# Generated: what are the three constituents of the basic protein ?
#
# Input:      author mary mcdonough murphy who collected individual impressions of to kill a mockingbird by several authors and public figures calls the book an astonishing phenomenon
# Actual:     who gathered impressions of to kill a mockingbird from other authors and famous people ?
# Generated: who wrote the author ?
#
# Input:      the recording industry association of america riaa listed beyoncé as the top certified artist of the 2000s with a total of 64 certifications
# Actual:     who cited beyoncé as being the top certified artist of the 2000s ?
# Generated: what was the name of the record record of the first female artist of america ?
#
# Input:      each boat is navigated by two sailors
# Actual:     how many people are in the vehicle for the ag2r race ?
# Generated: how many sailors are in the french ?
#
# Input:      believing that bond supplanted his role as son oberhauser killed his father and staged his own death subsequently adopting the name ernst stavro blofeld and going on to form spectre
# Actual:     what did oberhauser call himself after he faked his death ?
# Generated: what was the name of the name of the name of the name of the name of the name of ?
#
# Input:      in the precolonial era the area of present day new york city was inhabited by various bands of algonquian tribes of native americans including the lenape whose homeland known as lenapehoking included staten island the western portion of long island including the area that would become brooklyn and queens manhattan the bronx and the lower hudson valley
# Actual:     what was the name of the lenape homeland ?
# Generated: what was the name of the population of new york city ?
#
# Input:      governments also bailed out key financial institutions and implemented economic stimulus programs assuming significant additional financial commitments
# Actual:     who bailed out key financial institutions and implemented economic stimulus programs as an answer to the financial crisis of 2007 ?
# Generated: what is the financial financial financial status ?
#
# Input:      the overuse of antibiotics like penicillin and erythromycin has been associated with emerging antibiotic resistance since the 1950s
# Actual:     what is an example of bad treatment causing resistance ?
# Generated: what has been associated with developing tb ?
#
# Input:      traditional activities begin at the stroke of midnight with the drummers circle
# Actual:     what occurs at midnight preceding a football home game at notre dame ?
# Generated: what is the name of the traditional activities in the baroque period ?
#
# Input:      relative to the size of its economy iceland s banking collapse is the largest suffered by any country in economic history
# Actual:     relative to the size of its economy what country s banking collapse was the largest experienced by any country in economic history ?
# Generated: what is the biggest rainfall in the worst ?
#
# Input:      her early songs were personally driven and female empowerment themed compositions like independent women and survivor but after the start of her relationship with jay z she transitioned to more man tending anthems such as cater 2 u
# Actual:     with jay z what were her new themes ?
# Generated: what was the name of the first album that madonna was inspired by ?
#
# Input:      born in santo domingo of portuguese and african descent he arrived in manhattan during the winter of 1613 1614 trapping for pelts and trading with the local population as a representative of the dutch
# Actual:     during what season did juan rodriguez first come to new york ?
# Generated: where did broz speak in the winter ?
#
# Input:      in 1914 three neighbouring independent towns viz the county borough of plymouth the county borough of devonport and the urban district of east stonehouse were merged to form a single county borough
# Actual:     along with plymouth and devonport what location was merged into a county borough in 1914 ?
# Generated: how many towns were in southampton in 1914 ?
#
# Input:      throughout america s history dominance of one of the three branches has essentially been a see saw struggle between congress and the president
# Actual:     immediately following the civil war which branch of government was seen to have the greater amount of power ?
# Generated: how many branches have there been in america ?
#
# Input:      indeed in recent decades attention to whitehead s work has become more widespread with interest extending to intellectuals in europe and china and coming from such diverse fields as ecology physics biology education economics and psychology
# Actual:     in what areas of the world has interest in whitehead s work spread in recent decades ?
# Generated: what is the most popular with our interest in our research ?
#
# Input:      sentient beings always suffer throughout saṃsāra until they free themselves from this suffering dukkha by attaining nirvana
# Actual:     how are sentient beings freed from suffering ?
# Generated: what does nyaya mean ?
#
# Input:      although the chinese government was initially praised for its response to the quake especially in comparison to myanmar s ruling military junta s blockade of aid during cyclone nargis it then saw an erosion in confidence over the school construction scandal
# Actual:     over what scandal did the chinese government lose in public opinion ?
# Generated: what was the chinese government accused of ?
#
# Input:      this was also the first season without executive producer nigel lythgoe who left to focus on the international versions of his show so you think you can dance
# Actual:     what show did nigel lythgoe leave american idol to produce ?
# Generated: what did tony s producer have to be a result of the first season ?
#
# Input:      the following united nations member states were not included in the 2011 report north korea marshall islands monaco nauru san marino south sudan somalia and tuvalu
# Actual:     which east asian dictatorship was excluded from the 2011 report ?
# Generated: what was the name of the south country in burma ?
#
# Input:      what the los angeles times later called missing one of the biggest marketing opportunities in a generation contributed to pepsi losing market share by 2010 falling to third place from second in the united states
# Actual:     pepsico fell to what place by 2010 which is in part credited with refusing to sponsor american idol ?
# Generated: what was the name of the first major marketing trend in 2010 ?
#
# Input:      primarily inspired by architecture west s perfectionist tendencies led him to contact producer rick rubin fifteen days shy of its due date to strip down the record s sound in favor of a more minimalist approach
# Actual:     what was the inspiration behind kanye west s decision to call rick rubin ?
# Generated: how long did the sun react to the record ?
#
# Input:      in 1976 the future labour prime minister james callaghan launched what became known as the great debate on the education system
# Actual:     who initiated the scrutiny of the educational system in 1976 ?
# Generated: who was the future of the future of the future of the future ?
#
# Input:      her debut single crazy in love was named vh1 s greatest song of the 2000s nme s best track of the 00s and pop song of the century considered by rolling stone to be one of the 500 greatest songs of all time earned two grammy awards and is one of the best selling singles of all time at around 8 million copies
# Actual:     how many did crazy in love sell to become one of the greatest selling singles in history ?
# Generated: what was the name of queen s song ?
#
# Input:      at 27 million in 2012 new york s non hispanic white population is larger than the non hispanic white populations of los angeles 11 million chicago 865000 and houston 550000 combined
# Actual:     what is the non hispanic white population of houston ?
# Generated: how many white americans lived in new york ?
#
# Input:      key among his reckoning with political realities was a special election he called in november 2005 in which four ballot measures he sponsored were defeated
# Actual:     in what month of 2005 did schwarzenegger hold a special election ?
# Generated: when did nasser call his political political political political relations ?
#
# Input:      on october 22 2007 apple reported quarterly revenue of us 622 billion of which 3069 came from apple notebook sales 1922 from desktop sales and 26 from ipod sales
# Actual:     desktop computers made up how much of apple s revenue in the third quarter of 2007 ?
# Generated: what percentage of the sale of the sale of the sale of the sale of the sale of the sale ?
#
# Input:      sustainability in architecture was pioneered by frank lloyd wright in the 1960s by buckminster fuller and in the 1970s by architects such as ian mcharg and sim van der ryn in the us and brenda and robert vale in the uk and new zealand
# Actual:     who was known for focusing on the environment in the 1960s ?
# Generated: who developed sustainability in development ?
#
# Input:      the assembly of the republic is a single chamber parliament composed of 230 deputies elected for a four year term
# Actual:     for how long of a term are deputies elected ?
# Generated: how many people are there in the rsfsr ?
#
# Input:      upon its arrival in canberra the olympic flame was presented by chinese officials to local aboriginal elder agnes shea of the ngunnawal people
# Actual:     what is the name of the aboriginal elder who received the torch from chinese officials ?
# Generated: who presented the olympic olympic olympics ?
#
# Input:      the yarlung rulers of tibet also signed various peace treaties with the tang culminating in a treaty in 821 that fixed the borders between tibet and china
# Actual:     what year did tang and tibet sign a treaty to fix the borders ?
# Generated: what did the rulers of tibet sign peace with ?
#
# Input:      schwarzenegger defeated democrat cruz bustamante fellow republican tom mcclintock and others
# Actual:     who was schwarzenegger s closest rival in the gubernatorial race of 2003 ?
# Generated: what did the state of bush win ?
#
# Input:      23 year old candice glover won the season with kree harrison taking the runner up spot
# Actual:     who won this season of idol ?
# Generated: how old was the everton fc win ?
#
# Input:      the expenses of the funeral and monument amounting to 5000 francs were covered by jane stirling who also paid for the return of the composer s sister ludwika to warsaw
# Actual:     who paid for chopin s funeral ?
# Generated: how many apartment were covered by the palace ?
#
# Input:      it is a replica of the grotto at lourdes france where the virgin mary reputedly appeared to saint bernadette soubirous in 1858
# Actual:     to whom did the virgin mary allegedly appear in 1858 in lourdes france ?
# Generated: when did the virgin lady arrive to saint ?
#
# Input:      the last movement a brief 75 bar perpetuum mobile in which the hands play in unmodified octave unison throughout was found shocking and unmusical by contemporaries including schumann
# Actual:     which movement was found lacking in musicality by schumann ?
# Generated: what was the last movement in the crowd ?
#
# Input:      rather than composing the score once the film had moved into post production newman worked during filming
# Actual:     did thomas newman compose the score after filming or during filming ?
# Generated: who worked during the production of the film ?
#
# Input:      the ongoing conflict in darfur sudan which started in 2003 was declared a genocide by united states secretary of state colin powell on 9 september 2004 in testimony before the senate foreign relations committee
# Actual:     in 2003 what well known us secretary of state declared the situation in darfur as an act of genocide ?
# Generated: when did tony clinton die ?
#
# Input:      its projects range from shopping centres a cruise terminal a boulevard and to increase the population to 300000 and build 33000 dwellings
# Actual:     what is the population goal of the vision for plymouth ?
# Generated: what is the name of the market in the downtown center ?
#
# Input:      bill deronde replaced warwick as a director of the audition episodes while louis j horvitz replaced gregg gelfand as a director of the show
# Actual:     who directed the thirteenth season of american idol ?
# Generated: who replaced the director of the director of the director of the director of the film ?
#
# Input:      there has also been a related shift toward broadening the focus beyond the daily life of ordinary people increasingly research is set in settings such as scientific laboratories social movements governmental and nongovernmental organizations and businesses
# Actual:     what setting have anthropologists done more research in recently ?
# Generated: what is the focus of the focus of the daily life of ordinary people ?
#
# Input:      swaminathan krishnan assistant professor of civil engineering and geophysics at the california institute of technology said the earthquake occurred in the rural part of china
# Actual:     who was an assistant professor of civil engineering and geophysics at the california institute of technology ?
# Generated: what was the name of the first that occurred in the nanjing part of china ?
#
# Input:      after the awards show west stated in an interview that he was not joking and that beck needs to respect artistry he should have given his award to beyoncé
# Actual:     to who did kanye state that beck should hand his award over to ?
# Generated: what did the bbc show speech ?
#
# Input:      a total of 120 torchbearers were selected to participate in the event consisting of celebrities athletes and pro beijing camp politicians
# Actual:     how many torchbearers participated in the relay event in hong kong ?
# Generated: how many japanese were selected to prepare for the events ?
#
# Input:      according to this narrative shortly after the birth of young prince gautama an astrologer named asita visited the young prince s father suddhodana and prophesied that siddhartha would either become a great king or renounce the material world to become a holy man depending on whether he saw what life was like outside the palace walls
# Actual:     what was the name of the astrologer who visited prince gautama s father ?
# Generated: what was the illegitimate of man ?
#
# Input:      the undergraduate component of the university is organized into four colleges arts and letters science engineering business and the architecture school
# Actual:     how many individual colleges are part of notre dame ?
# Generated: how many colleges are in the university of ku ?
#
# Input:      neutering refers to the sterilization of animals usually by removal of the male s testicles or the female s ovaries and uterus in order to eliminate the ability to procreate and reduce sex drive
# Actual:     what is usually removed in female dogs to prevent pregnancy ?
# Generated: what is the name of the male reproductive and reproductive ?
#
# Input:      her debut single crazy in love was named vh1 s greatest song of the 2000s nme s best track of the 00s and pop song of the century considered by rolling stone to be one of the 500 greatest songs of all time earned two grammy awards and is one of the best selling singles of all time at around 8 million copies
# Actual:     how many grammy awards did crazy in love get ?
# Generated: what was the name of queen s album ?
#
# Input:      in a comment to the economist in early january 2011 the human development report office responded to a january 6 2011 article in the magazine which discusses the wolff et al paper
# Actual:     which magazine publication carried a statement from the human development report office in january 2011 ?
# Generated: what magazine interviewed the magazine in 2011 article ?
#
# Input:      antibiotics revolutionized medicine in the 20th century and have together with vaccination led to the near eradication of diseases such as tuberculosis in the developed world
# Actual:     when did antibiotics revolutinzed medicine ?
# Generated: what was the name of the study of antibiotics ?
#
# Input:      in a united states geological survey usgs study preliminary rupture models of the earthquake indicated displacement of up to 9 meters along a fault approximately 240 km long by 20 km deep
# Actual:     how large was the displacement ?
# Generated: what is the magnitude of the magnitude of the earthquake ?
#
# Input:      in april 2007 beyoncé embarked on the beyoncé experience her first worldwide concert tour visiting 97 venues and grossed over 24 million
# Actual:     what was the name of beyoncé s first international tour ?
# Generated: how many participants were in the world tour tour tour ?
#
# Input:      apple introduced a new 8 pin dock connector named lightning on september 12 2012 with their announcement of the iphone 5 the fifth generation ipod touch and the seventh generation ipod nano which all feature it
# Actual:     what new connector did apple unveil on september 12 2012 ?
# Generated: what was the name of apple s new charging connector ?
#
# Input:      the first collected edition was by breitkopf härtel 1878 1902
# Actual:     who released the first collection of chopin s works ?
# Generated: who was the first documented edition ?
#
# Input:      empirical therapy is usually initiated before the doctor knows the exact identification of microorgansim causing the infection as the identification process make take several days in the laboratory
# Actual:     how long does the identification process take ?
# Generated: what is the term for circadian therapy therapy ?
#
# Input:      desperate to keep west from defecting to another label then label head damon dash reluctantly signed west to roc a fella records
# Actual:     what record company eventually signed kanye west ?
# Generated: what was the name of the label that was the name of the label that was the name of the ?
#
# Input:      because of the magnitude of the quake and the media attention on china foreign nations and organizations immediately responded to the disaster by offering condolences and assistance
# Actual:     why did the world community notice the need for help ?
# Generated: why did the media attention on china contribute to the disaster ?
#
# Input:      queens is served by the queens borough public library the nation s second largest public library system while the brooklyn public library serves brooklyn
# Actual:     what is the name of the library system in queens ?
# Generated: what is the name of the largest public library in the public library ?
#
# Input:      roofs have been found to be a suitable place for solar cells as many people have discovered that they can collect energy directly from their homes this way
# Actual:     why are roofs a good place for solar panels ?
# Generated: what do roofs have ?
#
# Input:      these movements included besides buddhism various skeptics such as sanjaya belatthiputta atomists such as pakudha kaccayana materialists such as ajita kesakambali antinomians such as purana kassapa the most important ones in the 5th century bce were the ajivikas who emphasized the rule of fate the lokayata materialists the ajnanas agnostics and the jains who stressed that the soul must be freed from matter
# Actual:     what movement focused on the idea that the sould must be freed from matter ?
# Generated: what type of metalwork did the movements include ?
#
# Input:      the american idol songwriter contest was also held this season
# Actual:     how was the winning single chose on season seven of american idol ?
# Generated: what was the name of the american idol contest contest held ?
#
# Input:      the premiere drew a massive audience of 373 million viewers peaking in the last half hour with more than 41 million viewers
# Actual:     how many people watched the season premiere of american idol in 2007 ?
# Generated: how many viewers watched the audience of viewers in the last hour ?
#
# Input:      the original judges were record producer and music manager randy jackson pop singer and choreographer paula abdul and music executive and manager simon cowell
# Actual:     which original judge was a music executive ?
# Generated: what was the title of the original title of the original female ?
#
# Input:      a peripheral road system connecting the historic barbican on the east and union street to the west determines the principal form of the city centre even following pedestrianisation of the shopping centre in the late 1980s and continues to inform the present vision for plymouth developed by a team led by barcelona based architect david mackay in 2003 which calls for revivification of the city centre with mixed use and residential
# Actual:     who headed the team that created the vision for plymouth ?
# Generated: what is the name of the name of the east east ?
#
# Input:      this has led to widespread problems with antimicrobial and antibiotic resistance so much as to prompt the world health organization to classify antimicrobial resistance as a serious threat that is no longer a prediction for the future it is happening right now in every region of the world and has the potential to affect anyone of any age in any country
# Actual:     besides antimicrobial what did the overused medicine cause ?
# Generated: what is the world health security organization called ?
#
# Input:      in its 2013 parkscore ranking the trust for public land reported that the park system in new york city was the second best park system among the 50 most populous us cities behind the park system of minneapolis
# Actual:     the 2013 parkscore rating for nyc made nyc second in best park system to what other us city ?
# Generated: what ranking did public land in 2013 ?
#
# Input:      in march 2011 it was said on the wayback machine forum that the beta of the new wayback machine has a more complete and up to date index of all crawled materials into 2010 and will continue to be updated regularly
# Actual:     the newer version of the wayback machine included date up to and including what year ?
# Generated: what is the critical data that the critical data that the new data that the new data ?
#
# Input:      overall the protests were peaceful in nature although there were a few incidents such as the throwing of several water balloons in an attempt to extinguish the olympic flame and minor scuffles between olympic protesters and supporters from chinese immigrant communities
# Actual:     what was thrown to try and put out the flame ?
# Generated: what were the people in the protests ?
#
# Input:      the preludes were perhaps not intended to be played as a group and may even have been used by him and later pianists as generic preludes to others of his pieces or even to music by other composers as kenneth hamilton suggests he has noted a recording by ferruccio busoni of 1922 in which the prelude op 28 no 7 is followed by the étude op 10 no 5
# Actual:     who suggested that chopin s preludes were not intended to be played as a group ?
# Generated: what was the name of the whigs ?
#
# Input:      although the outbreak of world war i and the discovery of cheap oil in the 1930s discouraged the advancement of solar energy shuman s vision and basic design were resurrected in the 1970s with a new wave of interest in solar thermal energy
# Actual:     when was the interest in solar energy restored ?
# Generated: what was the name of the first light that was used in the 1930s ?
#
# Input:      hogeschool institutions in the flemish community of belgium such as the erasmus hogeschool brussel are currently undergoing a process of academization
# Actual:     what term refers to the process that a hogeschool undergoes before it s able to award master s degrees ?
# Generated: what is the name of the swiss university ?
#
# Input:      in october 1810 six months after fryderyk s birth the family moved to warsaw where his father acquired a post teaching french at the warsaw lyceum then housed in the saxon palace
# Actual:     when did chopin s family move to warsaw ?
# Generated: when did the austrian father acquire a post teaching ?
#
# Input:      fox announced on may 11 2015 that the fifteenth season would be the final season of american idol as such the season is expected to have an additional focus on the program s alumni
# Actual:     what year did fox announce the cancellation of american idol ?
# Generated: when did the last season of american idol announce ?
#
# Input:      house builders could use current architectural design in their work by combining features found in pattern books and architectural journals
# Actual:     what type of design did these texts allow the builders to incorporate ?
# Generated: what type of architecture did house house house house ?

# %%
model.get_diversity_metrics(checkpoint, x_test, y_test)
# Out:
# INFO:tensorflow:Restoring parameters from models/var-seq2seq-var-attn-7.ckpt
# 100%|██████████| 3/3 [17:11<00:00, 343.79s/it]
# Entropy = 2.274 | Distinct-1 = 0.147 | Distinct-2 = 0.210
